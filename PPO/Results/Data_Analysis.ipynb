# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open("Toy-Exoenzyme/returns_1000.json") as f:
    amylase_returns=json.load(f)

# %%
pd.DataFrame(amylase_returns).plot()
plt.title("Amylase")
plt.savefig("Amylase.png",dpi=300)

# %%
with open("Toy-NECOM/returns_1000.json") as f:
    auxotrophy_returns=json.load(f)

# %%
pd.DataFrame(auxotrophy_returns).plot()
plt.title("Auxotrophy")
plt.savefig("Auxotrphy.png",dpi=300)

# %%
with open("Toy-NECOM_Facultative/returns_1000.json") as f:
    facultative_returns=json.load(f)

# %%
pd.DataFrame(facultative_returns).plot()
plt.title("Facultative Syntrophy")
plt.savefig("Facultative Syntrophy.png",dpi=300)
