# %%
from mimetypes import init
from turtle import color
import Toolkit as tk
import ToyModel as tm
import torch
import torch.functional as F
import torch.nn as nn
import numpy as np
import pandas as pd
import pickle
import time
import ray
import os
import seaborn  as sns
import matplotlib.pyplot as plt
import warnings
import json
import rich
import multiprocessing as mp
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-02-17

# %%
NUM_CORES = 8
warnings.filterwarnings("ignore")

# %%
agent1=tk.Agent("agent1",
                model=tm.ToyModel_SA.copy(),
                actor_network=tk.NN,
                critic_network=tk.NN,
                clip=0.1,
                lr_actor=0.0001,
                lr_critic=0.001,
                grad_updates=10,
                optimizer_actor=torch.optim.Adam,
                optimizer_critic=torch.optim.Adam,
                observables=['agent1' ,'Glc', 'Starch'],
                actions=["Amylase_e"],
                gamma=1,
                tau=0.1
                )

agents=[agent1]
# Out:
# Read LP format model from file /var/folders/jk/fr50qn391k794svhntbw333c0000gn/T/tmp7thmvi7a.lp
# Reading time = 0.00 seconds
# : 7 rows, 18 columns, 44 nonzeros

# %%
env=tk.Environment(name="Toy-Exoenzyme-Single-agents",
                    agents=agents,
                    dilution_rate=0.0001,
                    initial_condition={"Glc":100,"agent1":0.1,"Starch":10},
                    inlet_conditions={"Starch":10},
                    extracellular_reactions=[{"reaction":{
                    "Glc":10,
                    "Starch":-0.1,},
                    "kinetics": (tk.general_kinetic,("Glc","Amylase"))}],
                    max_c={'Glc':100,
                           'agent1':10,  
                           'Starch':10,
                           },
                           dt=0.1,
                           episode_time=100,
                           number_of_batches=5000,
                           episodes_per_batch=int(NUM_CORES/2),
                           )
# Out:
# The following species are not in the community: ['Starch']
# Environment Toy-Exoenzyme-Single-agents created successfully!.

# %%
env.rewards={agent.name:[] for agent in env.agents}

if not os.path.exists(f"Results/{env.name}"):
	os.makedirs(f"Results/{env.name}")

for agent in env.agents:
	agent.model.solver="glpk"

for batch in range(env.number_of_batches):

	batch_obs,batch_acts, batch_log_probs, batch_rtgs=tk.rollout(env)
	for agent in env.agents:
		V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
		A_k = batch_rtgs[agent.name] - V.detach()   
		A_k = (A_k - A_k.mean()) / (A_k.std() + 1e-5) 
		if batch==0:
			rich.print("[bold yellow] Hold on, bringing the creitc network to range...[/bold yellow]")
			err=21
			while err>20:
				V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
				critic_loss = nn.MSELoss()(V, batch_rtgs[agent.name])
				agent.optimizer_value_.zero_grad()
				critic_loss.backward()
				agent.optimizer_value_.step() 
				err=critic_loss.item()
			rich.print("[bold green] Done![/bold green]")
		else: 
			
			for _ in range(agent.grad_updates):                                                      
				V, curr_log_probs = agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
				ratios = torch.exp(curr_log_probs - batch_log_probs[agent.name])
				surr1 = ratios * A_k.detach()
				surr2 = torch.clamp(ratios, 1 - agent.clip, 1 + agent.clip) * A_k
				actor_loss = (-torch.min(surr1, surr2)).mean()
				critic_loss = nn.MSELoss()(V, batch_rtgs[agent.name])
				agent.optimizer_policy_.zero_grad()
				actor_loss.backward(retain_graph=False)
				agent.optimizer_policy_.step()
				agent.optimizer_value_.zero_grad()
				critic_loss.backward()
				agent.optimizer_value_.step()                                                            
	
		if batch%500==0:
		
			with open(f"Results/{env.name}/{env.name}_{batch}.pkl", 'wb') as f:
				pickle.dump(env, f)
			with open(f"Results/{env.name}/observations_{batch}.pkl", 'wb') as f:
				pickle.dump(batch_obs,f)		
			with open(f"Results/{env.name}/actions_{batch}.pkl", 'wb') as f:
				pickle.dump(batch_acts,f)		
          		
		print(f"Batch {batch} finished:")
		for agent in env.agents:
			print(f"{agent.name} return is:  {np.mean(env.rewards[agent.name][-env.episodes_per_batch:])}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb Cell 5 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> 	agent.model.solver="glpk"
#       <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> for batch in range(env.number_of_batches):
# ---> <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> 	batch_obs,batch_acts, batch_log_probs, batch_rtgs=tk.rollout(env)
#      <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> 	for agent in env.agents:
#      <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a> 		V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
#
# File ~/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/Toolkit.py:386, in rollout(env)
#     383 for ep in range(env.episodes_per_batch):
#     384     # batch.append(run_episode_single(env))
#     385     batch.append(run_episode.remote(env))
# --> 386 batch=ray.get(batch)
#     387 for ep in range(env.episodes_per_batch):
#     388     for ag in env.agents:
#
# File ~/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages/ray/worker.py:1825, in get(object_refs, timeout)
#    1819     raise ValueError(
#    1820         "'object_refs' must either be an object ref "
#    1821         "or a list of object refs."
#    1822     )
#    1824 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 1825 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    1826 for i, value in enumerate(values):
#    1827     if isinstance(value, RayError):
#
# File ~/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages/ray/worker.py:364, in Worker.get_objects(self, object_refs, timeout)
#     358         raise TypeError(
#     359             f"Attempting to call `get` on the value {object_ref}, "
#     360             "which is not an ray.ObjectRef."
#     361         )
#     363 timeout_ms = int(timeout * 1000) if timeout else -1
# --> 364 data_metadata_pairs = self.core_worker.get_objects(
#     365     object_refs, self.current_task_id, timeout_ms
#     366 )
#     367 debugger_breakpoint = b""
#     368 for (data, metadata) in data_metadata_pairs:
#
# KeyboardInterrupt:

# %%
agent1=tk.Agent("agent1",
                model=tm.ToyModel_SA.copy(),
                actor_network=tk.NN,
                critic_network=tk.NN,
                clip=0.1,
                lr_actor=0.0001,
                lr_critic=0.001,
                grad_updates=10,
                optimizer_actor=torch.optim.Adam,
                optimizer_critic=torch.optim.Adam,
                observables=['agent1','agent2' ,'Glc', 'Starch'],
                actions=["Amylase_e"],
                gamma=1,
                tau=0.1
                )

agent2=tk.Agent("agent2",
                model=tm.ToyModel_SA.copy(),
                actor_network=tk.NN,
                critic_network=tk.NN,
                clip=0.1,
                lr_actor=0.0001,
                lr_critic=0.001,
                grad_updates=10,
                optimizer_actor=torch.optim.Adam,
                optimizer_critic=torch.optim.Adam,
                observables=['agent1','agent2', 'Glc', 'Starch'],
                actions=["Amylase_e"],
                gamma=1,
                tau=0.1
                )

agents=[agent1,agent2]

env=tk.Environment(name="Toy-Exoenzyme-Two-agents",
                    agents=agents,
                    dilution_rate=0.0001,
                    initial_condition={"Glc":100,"agent1":0.1,"agent2":0.1,"Starch":10},
                    inlet_conditions={"Starch":10},
                    extracellular_reactions=[{"reaction":{
                    "Glc":10,
                    "Starch":-0.1,},
                    "kinetics": (tk.general_kinetic,("Glc","Amylase"))}],
                    max_c={'Glc':100,
                           'agent1':10,  
                           'Starch':10,
                           },
                           dt=0.1,
                           episode_time=100,
                           number_of_batches=5000,
                           episodes_per_batch=int(NUM_CORES/2),
                           )
# Out:
# Read LP format model from file /var/folders/jk/fr50qn391k794svhntbw333c0000gn/T/tmpalrbsvhd.lp
# Reading time = 0.00 seconds
# : 7 rows, 18 columns, 44 nonzeros
# Read LP format model from file /var/folders/jk/fr50qn391k794svhntbw333c0000gn/T/tmp566lcqnu.lp
# Reading time = 0.00 seconds
# : 7 rows, 18 columns, 44 nonzeros
# The following species are not in the community: ['Starch']
# Environment Toy-Exoenzyme-Two-agents created successfully!.

# %%
env.rewards={agent.name:[] for agent in env.agents}

if not os.path.exists(f"Results/{env.name}"):
	os.makedirs(f"Results/{env.name}")

for agent in env.agents:
	agent.model.solver="glpk"

for batch in range(env.number_of_batches):

	batch_obs,batch_acts, batch_log_probs, batch_rtgs=tk.rollout(env)
	for agent in env.agents:
		V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
		A_k = batch_rtgs[agent.name] - V.detach()   
		A_k = (A_k - A_k.mean()) / (A_k.std() + 1e-5) 
		if batch==0:
			rich.print("[bold yellow] Hold on, bringing the creitc network to range...[/bold yellow]")
			err=21
			while err>20:
				V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
				critic_loss = nn.MSELoss()(V, batch_rtgs[agent.name])
				agent.optimizer_value_.zero_grad()
				critic_loss.backward()
				agent.optimizer_value_.step() 
				err=critic_loss.item()
			rich.print("[bold green] Done![/bold green]")
		else: 
			
			for _ in range(agent.grad_updates):                                                      
				V, curr_log_probs = agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
				ratios = torch.exp(curr_log_probs - batch_log_probs[agent.name])
				surr1 = ratios * A_k.detach()
				surr2 = torch.clamp(ratios, 1 - agent.clip, 1 + agent.clip) * A_k
				actor_loss = (-torch.min(surr1, surr2)).mean()
				critic_loss = nn.MSELoss()(V, batch_rtgs[agent.name])
				agent.optimizer_policy_.zero_grad()
				actor_loss.backward(retain_graph=False)
				agent.optimizer_policy_.step()
				agent.optimizer_value_.zero_grad()
				critic_loss.backward()
				agent.optimizer_value_.step()                                                            
	
		if batch%500==0:
		
			with open(f"Results/{env.name}/{env.name}_{batch}.pkl", 'wb') as f:
				pickle.dump(env, f)
			with open(f"Results/{env.name}/observations_{batch}.pkl", 'wb') as f:
				pickle.dump(batch_obs,f)		
			with open(f"Results/{env.name}/actions_{batch}.pkl", 'wb') as f:
				pickle.dump(batch_acts,f)		
          		
		print(f"Batch {batch} finished:")
		for agent in env.agents:
			print(f"{agent.name} return is:  {np.mean(env.rewards[agent.name][-env.episodes_per_batch:])}")
# Out:
#  Hold on, bringing the creitc network to range...
#  Done!
# Batch 0 finished:
# agent1 return is:  -834.9255180536776
# agent2 return is:  -815.9404837891703
#  Hold on, bringing the creitc network to range...
#  Done!
# Batch 0 finished:
# agent1 return is:  -834.9255180536776
# agent2 return is:  -815.9404837891703
# Batch 1 finished:
# agent1 return is:  -841.8440040666383
# agent2 return is:  -826.1826531004805
# Batch 1 finished:
# agent1 return is:  -841.8440040666383
# agent2 return is:  -826.1826531004805
# Batch 2 finished:
# agent1 return is:  -835.6765195038785
# agent2 return is:  -820.6359854544567
# Batch 2 finished:
# agent1 return is:  -835.6765195038785
# agent2 return is:  -820.6359854544567
# Batch 3 finished:
# agent1 return is:  -838.8587132565848
# agent2 return is:  -824.0484213947282
# Batch 3 finished:
# agent1 return is:  -838.8587132565848
# agent2 return is:  -824.0484213947282
# Batch 4 finished:
# agent1 return is:  -841.3364360564342
# agent2 return is:  -832.9258086808351
# Batch 4 finished:
# agent1 return is:  -841.3364360564342
# agent2 return is:  -832.9258086808351
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb Cell 7 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> 	agent.model.solver="glpk"
#       <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> for batch in range(env.number_of_batches):
# ---> <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> 	batch_obs,batch_acts, batch_log_probs, batch_rtgs=tk.rollout(env)
#      <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> 	for agent in env.agents:
#      <a href='vscode-notebook-cell:/Users/parsaghadermarzi/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/NECom.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> 		V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
#
# File ~/Desktop/Academics/Projects/Reinforcement_Learning_Modeling/PPO/Toolkit.py:386, in rollout(env)
#     383 for ep in range(env.episodes_per_batch):
#     384     # batch.append(run_episode_single(env))
#     385     batch.append(run_episode.remote(env))
# --> 386 batch=ray.get(batch)
#     387 for ep in range(env.episodes_per_batch):
#     388     for ag in env.agents:
#
# File ~/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages/ray/worker.py:1825, in get(object_refs, timeout)
#    1819     raise ValueError(
#    1820         "'object_refs' must either be an object ref "
#    1821         "or a list of object refs."
#    1822     )
#    1824 # TODO(ujvl): Consider how to allow user to retrieve the ready objects.
# -> 1825 values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#    1826 for i, value in enumerate(values):
#    1827     if isinstance(value, RayError):
#
# File ~/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages/ray/worker.py:364, in Worker.get_objects(self, object_refs, timeout)
#     358         raise TypeError(
#     359             f"Attempting to call `get` on the value {object_ref}, "
#     360             "which is not an ray.ObjectRef."
#     361         )
#     363 timeout_ms = int(timeout * 1000) if timeout else -1
# --> 364 data_metadata_pairs = self.core_worker.get_objects(
#     365     object_refs, self.current_task_id, timeout_ms
#     366 )
#     367 debugger_breakpoint = b""
#     368 for (data, metadata) in data_metadata_pairs:
#
# File python/ray/_raylet.pyx:1200, in ray._raylet.CoreWorker.get_objects()
#
# File python/ray/_raylet.pyx:169, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
agent1=tk.Agent("agent1",
				model=tm.Toy_Model_NE_Aux_1,
				actor_network=tk.NN,
				critic_network=tk.NN,
				clip=0.1,
				lr_actor=0.0001,
				lr_critic=0.001,
				grad_updates=1,
				optimizer_actor=torch.optim.Adam,
				optimizer_critic=torch.optim.Adam,       
				observables=['agent1','agent2','S',"A","B"],
				actions=['A_e','B_e'],
				gamma=1,
				)
agent2=tk.Agent("agent2",
				model=tm.Toy_Model_NE_Aux_2,
				actor_network=tk.NN,
				critic_network=tk.NN,
				clip=0.1,
				lr_actor=0.0001,
				lr_critic=0.001,
				grad_updates=1,
				optimizer_actor=torch.optim.Adam,
				optimizer_critic=torch.optim.Adam,       
				observables=['agent1','agent2','S',"A","B"],
				actions=['A_e','B_e'],
				gamma=1)
agents=[agent1,agent2]

env=tk.Environment(name="Toy-NECOM-Auxotrophs",
 					agents=agents,
 					dilution_rate=0.0001,
 					extracellular_reactions=[],
 					initial_condition={"S":100,"agent1":0.1,"agent2":0.1,"A":10,"B":10},
 					inlet_conditions={"S":100},
 					max_c={'S':100,
 						   'agent1':10,  
 						   'agent2':10,
 						   'A':10,
 						   'B':10,},
 							dt=0.1,
 							episode_time=20,
 							number_of_batches=5000,
 							episodes_per_batch=NUM_CORES,)

env.rewards={agent.name:[] for agent in env.agents}
if not os.path.exists(f"Results/{env.name}"):
	os.makedirs(f"Results/{env.name}")
for agent in env.agents:
	agent.model.solver="glpk"
for batch in range(env.number_of_batches):
	batch_obs,batch_acts, batch_log_probs, batch_rtgs=tk.rollout(env)
	for agent in env.agents:
		V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
		A_k = batch_rtgs[agent.name] - V.detach()   
		A_k = (A_k - A_k.mean()) / (A_k.std() + 1e-5) 
		if batch==0:
			rich.print("[bold yellow] Hold on, bringing the creitc network to range...[/bold yellow]")
			err=21
			while err>20:
				V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
				critic_loss = nn.MSELoss()(V, batch_rtgs[agent.name])
				agent.optimizer_value_.zero_grad()
				critic_loss.backward()
				agent.optimizer_value_.step() 
				err=critic_loss.item()
			rich.print("[bold green] Done![/bold green]")
		else: 			
			for _ in range(agent.grad_updates):                                                      
				V, curr_log_probs = agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
				ratios = torch.exp(curr_log_probs - batch_log_probs[agent.name])
				surr1 = ratios * A_k.detach()
				surr2 = torch.clamp(ratios, 1 - agent.clip, 1 + agent.clip) * A_k
				actor_loss = (-torch.min(surr1, surr2)).mean()
				critic_loss = nn.MSELoss()(V, batch_rtgs[agent.name])
				agent.optimizer_policy_.zero_grad()
				actor_loss.backward(retain_graph=False)
				agent.optimizer_policy_.step()
				agent.optimizer_value_.zero_grad()
				critic_loss.backward()
				agent.optimizer_value_.step()                                                            	
		if batch%500==0:		
			with open(f"Results/{env.name}/{env.name}_{batch}.pkl", 'wb') as f:
				pickle.dump(env, f)
			with open(f"Results/{env.name}/observations_{batch}.pkl", 'wb') as f:
				pickle.dump(batch_obs,f)		
			with open(f"Results/{env.name}/actions_{batch}.pkl", 'wb') as f:
				pickle.dump(batch_acts,f)		
        		
		print(f"Batch {batch} finished:")
		for agent in env.agents:
			print(f"{agent.name} return is:  {np.mean(env.rewards[agent.name][-env.episodes_per_batch:])}")
# Out:
# Environment Toy-NECOM-Auxotrophs created successfully!.
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
#  Hold on, bringing the creitc network to range...
#  Done!
# Batch 0 finished:
# agent1 return is:  -102.82565899524093
# agent2 return is:  -118.03315702760008
#  Hold on, bringing the creitc network to range...
#  Done!
# Batch 0 finished:
# agent1 return is:  -102.82565899524093
# agent2 return is:  -118.03315702760008
# Batch 1 finished:
# agent1 return is:  -103.57831438059497
# agent2 return is:  -113.90515704890768
# Batch 1 finished:
# agent1 return is:  -103.57831438059497
# agent2 return is:  -113.90515704890768
# Batch 2 finished:
# agent1 return is:  -99.323500669933
# agent2 return is:  -115.14740178373437
# Batch 2 finished:
# agent1 return is:  -99.323500669933
# agent2 return is:  -115.14740178373437
# Batch 3 finished:
# agent1 return is:  -104.32666871771434
# agent2 return is:  -113.02939454490607
# Batch 3 finished:
# agent1 return is:  -104.32666871771434
# agent2 return is:  -113.02939454490607
# Batch 4 finished:
# agent1 return is:  -102.20021536552858
# agent2 return is:  -117.17117543699368
# Batch 4 finished:
# agent1 return is:  -102.20021536552858
# agent2 return is:  -117.17117543699368
# Batch 5 finished:
# agent1 return is:  -100.32443320628015
# agent2 return is:  -115.28289007574278
# Batch 5 finished:
# agent1 return is:  -100.32443320628015
# agent2 return is:  -115.28289007574278
# Batch 6 finished:
# agent1 return is:  -97.32283219724599
# agent2 return is:  -117.66331131351686
# Batch 6 finished:
# agent1 return is:  -97.32283219724599
# agent2 return is:  -117.66331131351686
# Batch 7 finished:
# agent1 return is:  -105.20059403452662
# agent2 return is:  -113.15468618511095
# Batch 7 finished:
# agent1 return is:  -105.20059403452662
# agent2 return is:  -113.15468618511095
# Batch 8 finished:
# agent1 return is:  -100.45105041008146
# agent2 return is:  -115.78975429657106
# Batch 8 finished:
# agent1 return is:  -100.45105041008146
# agent2 return is:  -115.78975429657106
# Batch 9 finished:
# agent1 return is:  -102.45118469052444
# agent2 return is:  -116.28334756488812
# Batch 9 finished:
# agent1 return is:  -102.45118469052444
# agent2 return is:  -116.28334756488812
# Batch 10 finished:
# agent1 return is:  -100.20220881439596
# agent2 return is:  -116.15917163950058
# Batch 10 finished:
# agent1 return is:  -100.20220881439596
# agent2 return is:  -116.15917163950058
# Batch 11 finished:
# agent1 return is:  -98.94918228787239
# agent2 return is:  -110.6413697024296
# Batch 11 finished:
# agent1 return is:  -98.94918228787239
# agent2 return is:  -110.6413697024296
# Batch 12 finished:
# agent1 return is:  -100.94895849262048
# agent2 return is:  -113.1659044586041
# Batch 12 finished:
# agent1 return is:  -100.94895849262048
# agent2 return is:  -113.1659044586041
# Batch 13 finished:
# agent1 return is:  -103.07586686513204
# agent2 return is:  -111.38491482188473
# Batch 13 finished:
# agent1 return is:  -103.07586686513204
# agent2 return is:  -111.38491482188473
# Batch 14 finished:
# agent1 return is:  -101.07465402867011
# agent2 return is:  -108.01143753957824
# Batch 14 finished:
# agent1 return is:  -101.07465402867011
# agent2 return is:  -108.01143753957824
# Batch 15 finished:
# agent1 return is:  -99.57445355055239
# agent2 return is:  -114.40901077705456
# Batch 15 finished:
# agent1 return is:  -99.57445355055239
# agent2 return is:  -114.40901077705456
# Batch 16 finished:
# agent1 return is:  -99.44651425176764
# agent2 return is:  -115.0390379422889
# Batch 16 finished:
# agent1 return is:  -99.44651425176764
# agent2 return is:  -115.0390379422889
# Batch 17 finished:
# agent1 return is:  -100.82538816533119
# agent2 return is:  -114.77644964123523
# Batch 17 finished:
# agent1 return is:  -100.82538816533119
# agent2 return is:  -114.77644964123523
# Batch 18 finished:
# agent1 return is:  -106.20174849937271
# agent2 return is:  -111.14516698360208
# Batch 18 finished:
# agent1 return is:  -106.20174849937271
# agent2 return is:  -111.14516698360208
# Batch 19 finished:
# agent1 return is:  -103.6986587132391
# agent2 return is:  -114.77921061826038
# Batch 19 finished:
# agent1 return is:  -103.6986587132391
# agent2 return is:  -114.77921061826038
# Batch 20 finished:
# agent1 return is:  -100.07182117875266
# agent2 return is:  -115.77296052229515
# Batch 20 finished:
# agent1 return is:  -100.07182117875266
# agent2 return is:  -115.77296052229515
# Batch 21 finished:
# agent1 return is:  -100.19830583846698
# agent2 return is:  -113.2702051224251
# Batch 21 finished:
# agent1 return is:  -100.19830583846698
# agent2 return is:  -113.2702051224251
# Batch 22 finished:
# agent1 return is:  -97.19834132129296
# agent2 return is:  -109.89874867658543
# Batch 22 finished:
# agent1 return is:  -97.19834132129296
# agent2 return is:  -109.89874867658543
# Batch 23 finished:
# agent1 return is:  -101.82204745462919
# agent2 return is:  -112.90160554662768
# Batch 23 finished:
# agent1 return is:  -101.82204745462919
# agent2 return is:  -112.90160554662768
# Batch 24 finished:
# agent1 return is:  -101.19729347646154
# agent2 return is:  -112.39372886277503
# Batch 24 finished:
# agent1 return is:  -101.19729347646154
# agent2 return is:  -112.39372886277503
# Batch 25 finished:
# agent1 return is:  -99.57325912403553
# agent2 return is:  -105.25483308265463
# Batch 25 finished:
# agent1 return is:  -99.57325912403553
# agent2 return is:  -105.25483308265463
# Batch 26 finished:
# agent1 return is:  -100.94729897454702
# agent2 return is:  -111.64276404318178
# Batch 26 finished:
# agent1 return is:  -100.94729897454702
# agent2 return is:  -111.64276404318178
# Batch 27 finished:
# agent1 return is:  -100.32481982124295
# agent2 return is:  -113.90995368691713
# Batch 27 finished:
# agent1 return is:  -100.32481982124295
# agent2 return is:  -113.90995368691713
# Batch 28 finished:
# agent1 return is:  -97.19565126699871
# agent2 return is:  -112.13544743946218
# Batch 28 finished:
# agent1 return is:  -97.19565126699871
# agent2 return is:  -112.13544743946218
# Batch 29 finished:
# agent1 return is:  -97.19571357495548
# agent2 return is:  -111.40473871331417
# Batch 29 finished:
# agent1 return is:  -97.19571357495548
# agent2 return is:  -111.40473871331417
# Batch 30 finished:
# agent1 return is:  -95.44574601398634
# agent2 return is:  -114.28211195804373
# Batch 30 finished:
# agent1 return is:  -95.44574601398634
# agent2 return is:  -114.28211195804373
# Batch 31 finished:
# agent1 return is:  -93.44498329639362
# agent2 return is:  -108.39098893154572
# Batch 31 finished:
# agent1 return is:  -93.44498329639362
# agent2 return is:  -108.39098893154572
# Batch 32 finished:
# agent1 return is:  -100.69589494747322
# agent2 return is:  -109.1401189310151
# Batch 32 finished:
# agent1 return is:  -100.69589494747322
# agent2 return is:  -109.1401189310151
# Batch 33 finished:
# agent1 return is:  -99.57236789928086
# agent2 return is:  -111.78207664563462
# Batch 33 finished:
# agent1 return is:  -99.57236789928086
# agent2 return is:  -111.78207664563462
# Batch 34 finished:
# agent1 return is:  -96.32284809394135
# agent2 return is:  -111.64988596503287
# Batch 34 finished:
# agent1 return is:  -96.32284809394135
# agent2 return is:  -111.64988596503287
# Batch 35 finished:
# agent1 return is:  -99.32254819803808
# agent2 return is:  -110.76675150554131
# Batch 35 finished:
# agent1 return is:  -99.32254819803808
# agent2 return is:  -110.76675150554131
# Batch 36 finished:
# agent1 return is:  -97.69461753160388
# agent2 return is:  -111.90318228608737
# Batch 36 finished:
# agent1 return is:  -97.69461753160388
# agent2 return is:  -111.90318228608737
# Batch 37 finished:
# agent1 return is:  -97.56892818479137
# agent2 return is:  -112.89778002056252
# Batch 37 finished:
# agent1 return is:  -97.56892818479137
# agent2 return is:  -112.89778002056252
# Batch 38 finished:
# agent1 return is:  -100.82325839865908
# agent2 return is:  -108.2505723398132
# Batch 38 finished:
# agent1 return is:  -100.82325839865908
# agent2 return is:  -108.2505723398132
# Batch 39 finished:
# agent1 return is:  -100.57133512342094
# agent2 return is:  -108.51484821148082
# Batch 39 finished:
# agent1 return is:  -100.57133512342094
# agent2 return is:  -108.51484821148082
# Batch 40 finished:
# agent1 return is:  -96.32133129792733
# agent2 return is:  -109.50668815099841
# Batch 40 finished:
# agent1 return is:  -96.32133129792733
# agent2 return is:  -109.50668815099841
# Batch 41 finished:
# agent1 return is:  -98.32227512126036
# agent2 return is:  -106.50330188805538
# Batch 41 finished:
# agent1 return is:  -98.32227512126036
# agent2 return is:  -106.50330188805538
# Batch 42 finished:
# agent1 return is:  -94.19317972246041
# agent2 return is:  -112.87599456623911
# Batch 42 finished:
# agent1 return is:  -94.19317972246041
# agent2 return is:  -112.87599456623911
# Batch 43 finished:
# agent1 return is:  -95.44625228723831
# agent2 return is:  -105.49365240837027
# Batch 43 finished:
# agent1 return is:  -95.44625228723831
# agent2 return is:  -105.49365240837027
# Batch 44 finished:
# agent1 return is:  -98.94690751205144
# agent2 return is:  -110.77197547146821
# Batch 44 finished:
# agent1 return is:  -98.94690751205144
# agent2 return is:  -110.77197547146821
# Batch 45 finished:
# agent1 return is:  -99.56959156249695
# agent2 return is:  -112.76652805216452
# Batch 45 finished:
# agent1 return is:  -99.56959156249695
# agent2 return is:  -112.76652805216452
# Batch 46 finished:
# agent1 return is:  -101.69819227511726
# agent2 return is:  -112.89560375517846
# Batch 46 finished:
# agent1 return is:  -101.69819227511726
# agent2 return is:  -112.89560375517846
# Batch 47 finished:
# agent1 return is:  -96.19567668007662
# agent2 return is:  -107.00651039035405
# Batch 47 finished:
# agent1 return is:  -96.19567668007662
# agent2 return is:  -107.00651039035405
# Batch 48 finished:
# agent1 return is:  -96.07000101778979
# agent2 return is:  -108.37309004981918
# Batch 48 finished:
# agent1 return is:  -96.07000101778979
# agent2 return is:  -108.37309004981918
# Batch 49 finished:
# agent1 return is:  -97.82292982291837
# agent2 return is:  -105.87151717046339
# Batch 49 finished:
# agent1 return is:  -97.82292982291837
# agent2 return is:  -105.87151717046339
# Batch 50 finished:
# agent1 return is:  -93.56491706064782
# agent2 return is:  -109.62429182228556
# Batch 50 finished:
# agent1 return is:  -93.56491706064782
# agent2 return is:  -109.62429182228556
# Batch 51 finished:
# agent1 return is:  -97.69445734348737
# agent2 return is:  -103.75782445519481
# Batch 51 finished:
# agent1 return is:  -97.69445734348737
# agent2 return is:  -103.75782445519481
# Batch 52 finished:
# agent1 return is:  -100.82022993732248
# agent2 return is:  -113.5130978131136
# Batch 52 finished:
# agent1 return is:  -100.82022993732248
# agent2 return is:  -113.5130978131136
# Batch 53 finished:
# agent1 return is:  -98.3207179830957
# agent2 return is:  -106.24375855591721
# Batch 53 finished:
# agent1 return is:  -98.3207179830957
# agent2 return is:  -106.24375855591721
# Batch 54 finished:
# agent1 return is:  -99.57325702177157
# agent2 return is:  -109.88143702771836
# Batch 54 finished:
# agent1 return is:  -99.57325702177157
# agent2 return is:  -109.88143702771836
# Batch 55 finished:
# agent1 return is:  -95.694851402616
# agent2 return is:  -112.76575514010183
# Batch 55 finished:
# agent1 return is:  -95.694851402616
# agent2 return is:  -112.76575514010183
# Batch 56 finished:
# agent1 return is:  -91.81755635299807
# agent2 return is:  -107.23346196100476
# Batch 56 finished:
# agent1 return is:  -91.81755635299807
# agent2 return is:  -107.23346196100476
# Batch 57 finished:
# agent1 return is:  -99.19475340061008
# agent2 return is:  -110.50256749191517
# Batch 57 finished:
# agent1 return is:  -99.19475340061008
# agent2 return is:  -110.50256749191517
# Batch 58 finished:
# agent1 return is:  -90.4411670976622
# agent2 return is:  -107.64004690559555
# Batch 58 finished:
# agent1 return is:  -90.4411670976622
# agent2 return is:  -107.64004690559555
# Batch 59 finished:
# agent1 return is:  -94.81961302749772
# agent2 return is:  -106.89269597315533
# Batch 59 finished:
# agent1 return is:  -94.81961302749772
# agent2 return is:  -106.89269597315533
# Batch 60 finished:
# agent1 return is:  -92.19059528643996
# agent2 return is:  -104.73939931954453
# Batch 60 finished:
# agent1 return is:  -92.19059528643996
# agent2 return is:  -104.73939931954453
# Batch 61 finished:
# agent1 return is:  -94.9417822365233
# agent2 return is:  -109.62138765474127
# Batch 61 finished:
# agent1 return is:  -94.9417822365233
# agent2 return is:  -109.62138765474127
# Batch 62 finished:
# agent1 return is:  -93.94247382566019
# agent2 return is:  -105.62194449742816
# Batch 62 finished:
# agent1 return is:  -93.94247382566019
# agent2 return is:  -105.62194449742816
# Batch 63 finished:
# agent1 return is:  -98.57305291814015
# agent2 return is:  -104.98873831005719
# Batch 63 finished:
# agent1 return is:  -98.57305291814015
# agent2 return is:  -104.98873831005719
# Batch 64 finished:
# agent1 return is:  -92.31559689576379
# agent2 return is:  -106.74462893290875
# Batch 64 finished:
# agent1 return is:  -92.31559689576379
# agent2 return is:  -106.74462893290875
# Batch 65 finished:
# agent1 return is:  -100.94890618542792
# agent2 return is:  -107.74719837002661
# Batch 65 finished:
# agent1 return is:  -100.94890618542792
# agent2 return is:  -107.74719837002661
# Batch 66 finished:
# agent1 return is:  -92.06764743338634
# agent2 return is:  -104.99130883628436
# Batch 66 finished:
# agent1 return is:  -92.06764743338634
# agent2 return is:  -104.99130883628436
# Batch 67 finished:
# agent1 return is:  -90.81928625887298
# agent2 return is:  -101.723265386672
# Batch 67 finished:
# agent1 return is:  -90.81928625887298
# agent2 return is:  -101.723265386672
# Batch 68 finished:
# agent1 return is:  -94.56834626009089
# agent2 return is:  -104.72836822466934
# Batch 68 finished:
# agent1 return is:  -94.56834626009089
# agent2 return is:  -104.72836822466934
# Batch 69 finished:
# agent1 return is:  -94.94542831188136
# agent2 return is:  -106.74717161726655
# Batch 69 finished:
# agent1 return is:  -94.94542831188136
# agent2 return is:  -106.74717161726655
# Batch 70 finished:
# agent1 return is:  -97.06957211194768
# agent2 return is:  -98.33802413900112
# Batch 70 finished:
# agent1 return is:  -97.06957211194768
# agent2 return is:  -98.33802413900112
# Batch 71 finished:
# agent1 return is:  -97.44456661615763
# agent2 return is:  -102.47206022295265
# Batch 71 finished:
# agent1 return is:  -97.44456661615763
# agent2 return is:  -102.47206022295265
# Batch 72 finished:
# agent1 return is:  -94.56627463669727
# agent2 return is:  -105.00139544476174
# Batch 72 finished:
# agent1 return is:  -94.56627463669727
# agent2 return is:  -105.00139544476174
# Batch 73 finished:
# agent1 return is:  -94.31768338270209
# agent2 return is:  -107.61867375027796
# Batch 73 finished:
# agent1 return is:  -94.31768338270209
# agent2 return is:  -107.61867375027796
# Batch 74 finished:
# agent1 return is:  -94.31849295143729
# agent2 return is:  -101.11019660980725
# Batch 74 finished:
# agent1 return is:  -94.31849295143729
# agent2 return is:  -101.11019660980725
# Batch 75 finished:
# agent1 return is:  -93.6942999366867
# agent2 return is:  -99.70380276031095
# Batch 75 finished:
# agent1 return is:  -93.6942999366867
# agent2 return is:  -99.70380276031095
# Batch 76 finished:
# agent1 return is:  -93.19165346215392
# agent2 return is:  -107.23291228554713
# Batch 76 finished:
# agent1 return is:  -93.19165346215392
# agent2 return is:  -107.23291228554713
# Batch 77 finished:
# agent1 return is:  -99.94574912667414
# agent2 return is:  -102.85418690965666
# Batch 77 finished:
# agent1 return is:  -99.94574912667414
# agent2 return is:  -102.85418690965666
# Batch 78 finished:
# agent1 return is:  -96.44254387717334
# agent2 return is:  -105.74733607817666
# Batch 78 finished:
# agent1 return is:  -96.44254387717334
# agent2 return is:  -105.74733607817666
# Batch 79 finished:
# agent1 return is:  -92.94339076457783
# agent2 return is:  -100.85039458731066
# Batch 79 finished:
# agent1 return is:  -92.94339076457783
# agent2 return is:  -100.85039458731066
# Batch 80 finished:
# agent1 return is:  -92.81796342146961
# agent2 return is:  -99.07655218838767
# Batch 80 finished:
# agent1 return is:  -92.81796342146961
# agent2 return is:  -99.07655218838767
# Batch 81 finished:
# agent1 return is:  -92.44464469859412
# agent2 return is:  -101.98113286542016
# Batch 81 finished:
# agent1 return is:  -92.44464469859412
# agent2 return is:  -101.98113286542016
# Batch 82 finished:
# agent1 return is:  -94.69481738018686
# agent2 return is:  -99.72568311636519
# Batch 82 finished:
# agent1 return is:  -94.69481738018686
# agent2 return is:  -99.72568311636519
# Batch 83 finished:
# agent1 return is:  -94.4446193047962
# agent2 return is:  -102.59634040154987
# Batch 83 finished:
# agent1 return is:  -94.4446193047962
# agent2 return is:  -102.59634040154987
# Batch 84 finished:
# agent1 return is:  -95.69549366356804
# agent2 return is:  -103.72930387596668
# Batch 84 finished:
# agent1 return is:  -95.69549366356804
# agent2 return is:  -103.72930387596668
# Batch 85 finished:
# agent1 return is:  -97.94400178186062
# agent2 return is:  -100.22349237858634
# Batch 85 finished:
# agent1 return is:  -97.94400178186062
# agent2 return is:  -100.22349237858634
# Batch 86 finished:
# agent1 return is:  -97.19499547438951
# agent2 return is:  -100.08680189521053
# Batch 86 finished:
# agent1 return is:  -97.19499547438951
# agent2 return is:  -100.08680189521053
# Batch 87 finished:
# agent1 return is:  -91.19279221643421
# agent2 return is:  -98.96784105426781
# Batch 87 finished:
# agent1 return is:  -91.19279221643421
# agent2 return is:  -98.96784105426781
# Batch 88 finished:
# agent1 return is:  -92.69337753219448
# agent2 return is:  -98.08540727914675
# Batch 88 finished:
# agent1 return is:  -92.69337753219448
# agent2 return is:  -98.08540727914675
# Batch 89 finished:
# agent1 return is:  -92.56590664149934
# agent2 return is:  -103.0979227504736
# Batch 89 finished:
# agent1 return is:  -92.56590664149934
# agent2 return is:  -103.0979227504736
# Batch 90 finished:
# agent1 return is:  -90.06774161699572
# agent2 return is:  -100.9640470180128
# Batch 90 finished:
# agent1 return is:  -90.06774161699572
# agent2 return is:  -100.9640470180128
# Batch 91 finished:
# agent1 return is:  -93.4408807068338
# agent2 return is:  -96.7117674578503
# Batch 91 finished:
# agent1 return is:  -93.4408807068338
# agent2 return is:  -96.7117674578503
# Batch 92 finished:
# agent1 return is:  -93.31714074384519
# agent2 return is:  -100.4677227704266
# Batch 92 finished:
# agent1 return is:  -93.31714074384519
# agent2 return is:  -100.4677227704266
# Batch 93 finished:
# agent1 return is:  -88.81378982610688
# agent2 return is:  -99.58848893360434
# Batch 93 finished:
# agent1 return is:  -88.81378982610688
# agent2 return is:  -99.58848893360434
# Batch 94 finished:
# agent1 return is:  -88.93923962172542
# agent2 return is:  -100.07880562764214
# Batch 94 finished:
# agent1 return is:  -88.93923962172542
# agent2 return is:  -100.07880562764214
# Batch 95 finished:
# agent1 return is:  -95.4442646926383
# agent2 return is:  -103.72002205680417
# Batch 95 finished:
# agent1 return is:  -95.4442646926383
# agent2 return is:  -103.72002205680417
# Batch 96 finished:
# agent1 return is:  -93.6912733582441
# agent2 return is:  -94.0776761869655
# Batch 96 finished:
# agent1 return is:  -93.6912733582441
# agent2 return is:  -94.0776761869655
# Batch 97 finished:
# agent1 return is:  -91.19171206640138
# agent2 return is:  -96.31921002100941
# Batch 97 finished:
# agent1 return is:  -91.19171206640138
# agent2 return is:  -96.31921002100941
# Batch 98 finished:
# agent1 return is:  -91.81560091990237
# agent2 return is:  -93.93524675045371
# Batch 98 finished:
# agent1 return is:  -91.81560091990237
# agent2 return is:  -93.93524675045371
# Batch 99 finished:
# agent1 return is:  -91.44228416194571
# agent2 return is:  -91.43351670948942
# Batch 99 finished:
# agent1 return is:  -91.44228416194571
# agent2 return is:  -91.43351670948942
# Batch 100 finished:
# agent1 return is:  -93.19241792622455
# agent2 return is:  -99.82650152782492
# Batch 100 finished:
# agent1 return is:  -93.19241792622455
# agent2 return is:  -99.82650152782492
# Batch 101 finished:
# agent1 return is:  -91.56603971961403
# agent2 return is:  -96.4345118841506
# Batch 101 finished:
# agent1 return is:  -91.56603971961403
# agent2 return is:  -96.4345118841506
# Batch 102 finished:
# agent1 return is:  -86.81245600255733
# agent2 return is:  -95.69007321150374
# Batch 102 finished:
# agent1 return is:  -86.81245600255733
# agent2 return is:  -95.69007321150374
# Batch 103 finished:
# agent1 return is:  -90.314011997872
# agent2 return is:  -96.07672172691954
# Batch 103 finished:
# agent1 return is:  -90.314011997872
# agent2 return is:  -96.07672172691954
# Batch 104 finished:
# agent1 return is:  -86.81475771996915
# agent2 return is:  -95.54980764620915
# Batch 104 finished:
# agent1 return is:  -86.81475771996915
# agent2 return is:  -95.54980764620915
# Batch 105 finished:
# agent1 return is:  -89.43800123990138
# agent2 return is:  -90.0512688686515
# Batch 105 finished:
# agent1 return is:  -89.43800123990138
# agent2 return is:  -90.0512688686515
# Batch 106 finished:
# agent1 return is:  -88.81562255416083
# agent2 return is:  -94.05325374523596
# Batch 106 finished:
# agent1 return is:  -88.81562255416083
# agent2 return is:  -94.05325374523596
# Batch 107 finished:
# agent1 return is:  -89.18960894023262
# agent2 return is:  -89.15796638267904
# Batch 107 finished:
# agent1 return is:  -89.18960894023262
# agent2 return is:  -89.15796638267904
# Batch 108 finished:
# agent1 return is:  -87.56095210176393
# agent2 return is:  -90.66166132308504
# Batch 108 finished:
# agent1 return is:  -87.56095210176393
# agent2 return is:  -90.66166132308504
# Batch 109 finished:
# agent1 return is:  -88.93871710362468
# agent2 return is:  -90.41492212601037
# Batch 109 finished:
# agent1 return is:  -88.93871710362468
# agent2 return is:  -90.41492212601037
# Batch 110 finished:
# agent1 return is:  -92.1889210063294
# agent2 return is:  -90.15058137203096
# Batch 110 finished:
# agent1 return is:  -92.1889210063294
# agent2 return is:  -90.15058137203096
# Batch 111 finished:
# agent1 return is:  -89.43868796756948
# agent2 return is:  -90.65189135812548
# Batch 111 finished:
# agent1 return is:  -89.43868796756948
# agent2 return is:  -90.65189135812548
# Batch 112 finished:
# agent1 return is:  -95.69334542602722
# agent2 return is:  -87.52627651874178
# Batch 112 finished:
# agent1 return is:  -95.69334542602722
# agent2 return is:  -87.52627651874178
# Batch 113 finished:
# agent1 return is:  -92.43890742168219
# agent2 return is:  -85.99635067813594
# Batch 113 finished:
# agent1 return is:  -92.43890742168219
# agent2 return is:  -85.99635067813594
# Batch 114 finished:
# agent1 return is:  -91.56492860716384
# agent2 return is:  -90.77793816042922
# Batch 114 finished:
# agent1 return is:  -91.56492860716384
# agent2 return is:  -90.77793816042922
# Batch 115 finished:
# agent1 return is:  -86.3117267369281
# agent2 return is:  -83.25096744794796
# Batch 115 finished:
# agent1 return is:  -86.3117267369281
# agent2 return is:  -83.25096744794796
# Batch 116 finished:
# agent1 return is:  -88.06243688092034
# agent2 return is:  -87.87024025973062
# Batch 116 finished:
# agent1 return is:  -88.06243688092034
# agent2 return is:  -87.87024025973062
# Batch 117 finished:
# agent1 return is:  -87.93612658107313
# agent2 return is:  -82.8510839362583
# Batch 117 finished:
# agent1 return is:  -87.93612658107313
# agent2 return is:  -82.8510839362583
# Batch 118 finished:
# agent1 return is:  -90.94122906841088
# agent2 return is:  -84.61931904280371
# Batch 118 finished:
# agent1 return is:  -90.94122906841088
# agent2 return is:  -84.61931904280371
# Batch 119 finished:
# agent1 return is:  -84.56084330127572
# agent2 return is:  -84.36160194084232
# Batch 119 finished:
# agent1 return is:  -84.56084330127572
# agent2 return is:  -84.36160194084232
# Batch 120 finished:
# agent1 return is:  -84.05862298224959
# agent2 return is:  -85.8847126675191
# Batch 120 finished:
# agent1 return is:  -84.05862298224959
# agent2 return is:  -85.8847126675191
# Batch 121 finished:
# agent1 return is:  -88.81254827851595
# agent2 return is:  -81.59442861536829
# Batch 121 finished:
# agent1 return is:  -88.81254827851595
# agent2 return is:  -81.59442861536829
# Batch 122 finished:
# agent1 return is:  -86.56370447014825
# agent2 return is:  -81.97853811646885
# Batch 122 finished:
# agent1 return is:  -86.56370447014825
# agent2 return is:  -81.97853811646885
# Batch 123 finished:
# agent1 return is:  -89.4366819376123
# agent2 return is:  -79.59691124246163
# Batch 123 finished:
# agent1 return is:  -89.4366819376123
# agent2 return is:  -79.59691124246163
# Batch 124 finished:
# agent1 return is:  -84.05830217222248
# agent2 return is:  -82.48848147582653
# Batch 124 finished:
# agent1 return is:  -84.05830217222248
# agent2 return is:  -82.48848147582653
# Batch 125 finished:
# agent1 return is:  -88.68592928279077
# agent2 return is:  -80.83816175502074
# Batch 125 finished:
# agent1 return is:  -88.68592928279077
# agent2 return is:  -80.83816175502074
# Batch 126 finished:
# agent1 return is:  -87.937104160751
# agent2 return is:  -73.81622759021326
# Batch 126 finished:
# agent1 return is:  -87.937104160751
# agent2 return is:  -73.81622759021326
# Batch 127 finished:
# agent1 return is:  -89.81402343056675
# agent2 return is:  -75.9360020788095
# Batch 127 finished:
# agent1 return is:  -89.81402343056675
# agent2 return is:  -75.9360020788095
# Batch 128 finished:
# agent1 return is:  -86.81497619712538
# agent2 return is:  -76.07104220015627
# Batch 128 finished:
# agent1 return is:  -86.81497619712538
# agent2 return is:  -76.07104220015627
# Batch 129 finished:
# agent1 return is:  -82.06371328605533
# agent2 return is:  -77.45936199071123
# Batch 129 finished:
# agent1 return is:  -82.06371328605533
# agent2 return is:  -77.45936199071123
# Batch 130 finished:
# agent1 return is:  -87.93837636079809
# agent2 return is:  -73.17176634599119
# Batch 130 finished:
# agent1 return is:  -87.93837636079809
# agent2 return is:  -73.17176634599119
# Batch 131 finished:
# agent1 return is:  -82.05822444390256
# agent2 return is:  -75.31173090206934
# Batch 131 finished:
# agent1 return is:  -82.05822444390256
# agent2 return is:  -75.31173090206934
# Batch 132 finished:
# agent1 return is:  -86.68786059190313
# agent2 return is:  -73.40848137809324
# Batch 132 finished:
# agent1 return is:  -86.68786059190313
# agent2 return is:  -73.40848137809324
# Batch 133 finished:
# agent1 return is:  -84.06294575613217
# agent2 return is:  -72.5361075489599
# Batch 133 finished:
# agent1 return is:  -84.06294575613217
# agent2 return is:  -72.5361075489599
# Batch 134 finished:
# agent1 return is:  -88.06258526323259
# agent2 return is:  -71.91678900729724
# Batch 134 finished:
# agent1 return is:  -88.06258526323259
# agent2 return is:  -71.91678900729724
# Batch 135 finished:
# agent1 return is:  -85.31147012289225
# agent2 return is:  -71.52912965896179
# Batch 135 finished:
# agent1 return is:  -85.31147012289225
# agent2 return is:  -71.52912965896179
# Batch 136 finished:
# agent1 return is:  -85.43543156066345
# agent2 return is:  -70.52565107430733
# Batch 136 finished:
# agent1 return is:  -85.43543156066345
# agent2 return is:  -70.52565107430733
# Batch 137 finished:
# agent1 return is:  -84.81548104991879
# agent2 return is:  -70.16202284358657
# Batch 137 finished:
# agent1 return is:  -84.81548104991879
# agent2 return is:  -70.16202284358657
# Batch 138 finished:
# agent1 return is:  -84.18701850210041
# agent2 return is:  -70.65282371660544
# Batch 138 finished:
# agent1 return is:  -84.18701850210041
# agent2 return is:  -70.65282371660544
# Batch 139 finished:
# agent1 return is:  -84.4368570126769
# agent2 return is:  -70.99570356310804
# Batch 139 finished:
# agent1 return is:  -84.4368570126769
# agent2 return is:  -70.99570356310804
# Batch 140 finished:
# agent1 return is:  -88.06478194330268
# agent2 return is:  -65.96878453321692
# Batch 140 finished:
# agent1 return is:  -88.06478194330268
# agent2 return is:  -65.96878453321692
# Batch 141 finished:
# agent1 return is:  -87.43400943353078
# agent2 return is:  -59.18796086915479
# Batch 141 finished:
# agent1 return is:  -87.43400943353078
# agent2 return is:  -59.18796086915479
# Batch 142 finished:
# agent1 return is:  -87.81269768359766
# agent2 return is:  -59.55166680983406
# Batch 142 finished:
# agent1 return is:  -87.81269768359766
# agent2 return is:  -59.55166680983406
# Batch 143 finished:
# agent1 return is:  -87.5628833638219
# agent2 return is:  -60.44162633109635
# Batch 143 finished:
# agent1 return is:  -87.5628833638219
# agent2 return is:  -60.44162633109635
# Batch 144 finished:
# agent1 return is:  -86.68647468751911
# agent2 return is:  -58.16283971242963
# Batch 144 finished:
# agent1 return is:  -86.68647468751911
# agent2 return is:  -58.16283971242963
# Batch 145 finished:
# agent1 return is:  -86.68755428032414
# agent2 return is:  -63.18303569549359
# Batch 145 finished:
# agent1 return is:  -86.68755428032414
# agent2 return is:  -63.18303569549359
# Batch 146 finished:
# agent1 return is:  -85.06100636737341
# agent2 return is:  -55.52019104528212
# Batch 146 finished:
# agent1 return is:  -85.06100636737341
# agent2 return is:  -55.52019104528212
# Batch 147 finished:
# agent1 return is:  -81.18330112579288
# agent2 return is:  -53.2346654483846
# Batch 147 finished:
# agent1 return is:  -81.18330112579288
# agent2 return is:  -53.2346654483846
# Batch 148 finished:
# agent1 return is:  -83.4350563848896
# agent2 return is:  -57.66251649218374
# Batch 148 finished:
# agent1 return is:  -83.4350563848896
# agent2 return is:  -57.66251649218374
# Batch 149 finished:
# agent1 return is:  -82.43369868164734
# agent2 return is:  -55.61226076769347
# Batch 149 finished:
# agent1 return is:  -82.43369868164734
# agent2 return is:  -55.61226076769347
# Batch 150 finished:
# agent1 return is:  -85.80948553071948
# agent2 return is:  -52.82626898612021
# Batch 150 finished:
# agent1 return is:  -85.80948553071948
# agent2 return is:  -52.82626898612021
# Batch 151 finished:
# agent1 return is:  -84.43336220892925
# agent2 return is:  -52.96651002233286
# Batch 151 finished:
# agent1 return is:  -84.43336220892925
# agent2 return is:  -52.96651002233286
# Batch 152 finished:
# agent1 return is:  -81.80848398457258
# agent2 return is:  -51.80514641278227
# Batch 152 finished:
# agent1 return is:  -81.80848398457258
# agent2 return is:  -51.80514641278227
# Batch 153 finished:
# agent1 return is:  -84.05905998127969
# agent2 return is:  -50.691746257475884
# Batch 153 finished:
# agent1 return is:  -84.05905998127969
# agent2 return is:  -50.691746257475884
# Batch 154 finished:
# agent1 return is:  -84.683518062713
# agent2 return is:  -50.98694999442123
# Batch 154 finished:
# agent1 return is:  -84.683518062713
# agent2 return is:  -50.98694999442123
# Batch 155 finished:
# agent1 return is:  -84.93389091634566
# agent2 return is:  -42.448908214075004
# Batch 155 finished:
# agent1 return is:  -84.93389091634566
# agent2 return is:  -42.448908214075004
# Batch 156 finished:
# agent1 return is:  -80.05557277463215
# agent2 return is:  -42.66652863609852
# Batch 156 finished:
# agent1 return is:  -80.05557277463215
# agent2 return is:  -42.66652863609852
# Batch 157 finished:
# agent1 return is:  -83.18244623633045
# agent2 return is:  -40.894945087275396
# Batch 157 finished:
# agent1 return is:  -83.18244623633045
# agent2 return is:  -40.894945087275396
# Batch 158 finished:
# agent1 return is:  -89.06416669854869
# agent2 return is:  -40.90687336805048
# Batch 158 finished:
# agent1 return is:  -89.06416669854869
# agent2 return is:  -40.90687336805048
# Batch 159 finished:
# agent1 return is:  -86.18625629576853
# agent2 return is:  -41.71613929498679
# Batch 159 finished:
# agent1 return is:  -86.18625629576853
# agent2 return is:  -41.71613929498679
# Batch 160 finished:
# agent1 return is:  -78.43326116294594
# agent2 return is:  -40.4895781785708
# Batch 160 finished:
# agent1 return is:  -78.43326116294594
# agent2 return is:  -40.4895781785708
# Batch 161 finished:
# agent1 return is:  -82.93343411038543
# agent2 return is:  -38.56120528530694
# Batch 161 finished:
# agent1 return is:  -82.93343411038543
# agent2 return is:  -38.56120528530694
# Batch 162 finished:
# agent1 return is:  -86.80836042257195
# agent2 return is:  -37.66082698235729
# Batch 162 finished:
# agent1 return is:  -86.80836042257195
# agent2 return is:  -37.66082698235729
# Batch 163 finished:
# agent1 return is:  -86.31221150365391
# agent2 return is:  -37.03390488294525
# Batch 163 finished:
# agent1 return is:  -86.31221150365391
# agent2 return is:  -37.03390488294525
# Batch 164 finished:
# agent1 return is:  -85.80984618010373
# agent2 return is:  -35.718522326394954
# Batch 164 finished:
# agent1 return is:  -85.80984618010373
# agent2 return is:  -35.718522326394954
# Batch 165 finished:
# agent1 return is:  -82.1812717616609
# agent2 return is:  -32.05564317549261
# Batch 165 finished:
# agent1 return is:  -82.1812717616609
# agent2 return is:  -32.05564317549261
# Batch 166 finished:
# agent1 return is:  -82.1790591131659
# agent2 return is:  -29.778804160479176
# Batch 166 finished:
# agent1 return is:  -82.1790591131659
# agent2 return is:  -29.778804160479176
# Batch 167 finished:
# agent1 return is:  -79.55514728450241
# agent2 return is:  -29.539433962790277
# Batch 167 finished:
# agent1 return is:  -79.55514728450241
# agent2 return is:  -29.539433962790277
# Batch 168 finished:
# agent1 return is:  -80.93085274370557
# agent2 return is:  -29.1560078111033
# Batch 168 finished:
# agent1 return is:  -80.93085274370557
# agent2 return is:  -29.1560078111033
# Batch 169 finished:
# agent1 return is:  -83.30754321601691
# agent2 return is:  -27.71127775417832
# Batch 169 finished:
# agent1 return is:  -83.30754321601691
# agent2 return is:  -27.71127775417832
# Batch 170 finished:
# agent1 return is:  -81.4343359226163
# agent2 return is:  -24.047462997273698
# Batch 170 finished:
# agent1 return is:  -81.4343359226163
# agent2 return is:  -24.047462997273698
# Batch 171 finished:
# agent1 return is:  -89.68516724299937
# agent2 return is:  -25.923432342716943
# Batch 171 finished:
# agent1 return is:  -89.68516724299937
# agent2 return is:  -25.923432342716943
# Batch 172 finished:
# agent1 return is:  -84.18321155394042
# agent2 return is:  -22.683222864306067
# Batch 172 finished:
# agent1 return is:  -84.18321155394042
# agent2 return is:  -22.683222864306067
# Batch 173 finished:
# agent1 return is:  -83.43569438354359
# agent2 return is:  -19.889563660107243
# Batch 173 finished:
# agent1 return is:  -83.43569438354359
# agent2 return is:  -19.889563660107243
# Batch 174 finished:
# agent1 return is:  -81.5587931352411
# agent2 return is:  -21.75827699898326
# Batch 174 finished:
# agent1 return is:  -81.5587931352411
# agent2 return is:  -21.75827699898326
# Batch 175 finished:
# agent1 return is:  -80.05857647036032
# agent2 return is:  -19.067448161669915
# Batch 175 finished:
# agent1 return is:  -80.05857647036032
# agent2 return is:  -19.067448161669915
# Batch 176 finished:
# agent1 return is:  -80.30865998917119
# agent2 return is:  -20.446335533001978
# Batch 176 finished:
# agent1 return is:  -80.30865998917119
# agent2 return is:  -20.446335533001978
# Batch 177 finished:
# agent1 return is:  -79.05550075088169
# agent2 return is:  -20.778244164204555
# Batch 177 finished:
# agent1 return is:  -79.05550075088169
# agent2 return is:  -20.778244164204555
# Batch 178 finished:
# agent1 return is:  -81.80705295335993
# agent2 return is:  -20.47788210387989
# Batch 178 finished:
# agent1 return is:  -81.80705295335993
# agent2 return is:  -20.47788210387989
# Batch 179 finished:
# agent1 return is:  -79.92990541907167
# agent2 return is:  -17.697338817910932
# Batch 179 finished:
# agent1 return is:  -79.92990541907167
# agent2 return is:  -17.697338817910932
# Batch 180 finished:
# agent1 return is:  -80.93346699880473
# agent2 return is:  -19.304086943269418
# Batch 180 finished:
# agent1 return is:  -80.93346699880473
# agent2 return is:  -19.304086943269418
# Batch 181 finished:
# agent1 return is:  -79.93277295196094
# agent2 return is:  -16.038010125364735
# Batch 181 finished:
# agent1 return is:  -79.93277295196094
# agent2 return is:  -16.038010125364735
# Batch 182 finished:
# agent1 return is:  -84.80901027704125
# agent2 return is:  -14.96442385722982
# Batch 182 finished:
# agent1 return is:  -84.80901027704125
# agent2 return is:  -14.96442385722982
# Batch 183 finished:
# agent1 return is:  -85.05654139666683
# agent2 return is:  -18.22250211485264
# Batch 183 finished:
# agent1 return is:  -85.05654139666683
# agent2 return is:  -18.22250211485264
# Batch 184 finished:
# agent1 return is:  -80.68394114873753
# agent2 return is:  -17.634780802997405
# Batch 184 finished:
# agent1 return is:  -80.68394114873753
# agent2 return is:  -17.634780802997405
# Batch 185 finished:
# agent1 return is:  -79.93128235162487
# agent2 return is:  -15.196807745314505
# Batch 185 finished:
# agent1 return is:  -79.93128235162487
# agent2 return is:  -15.196807745314505
# Batch 186 finished:
# agent1 return is:  -80.80563273042341
# agent2 return is:  -17.409697941967174
# Batch 186 finished:
# agent1 return is:  -80.80563273042341
# agent2 return is:  -17.409697941967174
# Batch 187 finished:
# agent1 return is:  -79.80624080766958
# agent2 return is:  -16.635997414477398
# Batch 187 finished:
# agent1 return is:  -79.80624080766958
# agent2 return is:  -16.635997414477398
# Batch 188 finished:
# agent1 return is:  -85.3086103453405
# agent2 return is:  -15.731735378227832
# Batch 188 finished:
# agent1 return is:  -85.3086103453405
# agent2 return is:  -15.731735378227832
# Batch 189 finished:
# agent1 return is:  -80.17704586772811
# agent2 return is:  -11.775060034056644
# Batch 189 finished:
# agent1 return is:  -80.17704586772811
# agent2 return is:  -11.775060034056644
# Batch 190 finished:
# agent1 return is:  -76.80095303283834
# agent2 return is:  -12.748649101740671
# Batch 190 finished:
# agent1 return is:  -76.80095303283834
# agent2 return is:  -12.748649101740671
# Batch 191 finished:
# agent1 return is:  -77.05510820555776
# agent2 return is:  -11.412362746376225
# Batch 191 finished:
# agent1 return is:  -77.05510820555776
# agent2 return is:  -11.412362746376225
# Batch 192 finished:
# agent1 return is:  -85.55714593008645
# agent2 return is:  -12.270730811084652
# Batch 192 finished:
# agent1 return is:  -85.55714593008645
# agent2 return is:  -12.270730811084652
# Batch 193 finished:
# agent1 return is:  -80.55620796514214
# agent2 return is:  -14.416662836416954
# Batch 193 finished:
# agent1 return is:  -80.55620796514214
# agent2 return is:  -14.416662836416954
# Batch 194 finished:
# agent1 return is:  -79.80169515214203
# agent2 return is:  -11.92709634196849
# Batch 194 finished:
# agent1 return is:  -79.80169515214203
# agent2 return is:  -11.92709634196849
# Batch 195 finished:
# agent1 return is:  -81.43137375720924
# agent2 return is:  -9.954904428674563
# Batch 195 finished:
# agent1 return is:  -81.43137375720924
# agent2 return is:  -9.954904428674563
# Batch 196 finished:
# agent1 return is:  -83.05829368529183
# agent2 return is:  -10.707524465067863
# Batch 196 finished:
# agent1 return is:  -83.05829368529183
# agent2 return is:  -10.707524465067863
# Batch 197 finished:
# agent1 return is:  -75.80542677388434
# agent2 return is:  -12.050767636333234
# Batch 197 finished:
# agent1 return is:  -75.80542677388434
# agent2 return is:  -12.050767636333234
# Batch 198 finished:
# agent1 return is:  -74.67968505527779
# agent2 return is:  -10.826398571110683
# Batch 198 finished:
# agent1 return is:  -74.67968505527779
# agent2 return is:  -10.826398571110683
# Batch 199 finished:
# agent1 return is:  -76.30116769032199
# agent2 return is:  -10.563111816197253
# Batch 199 finished:
# agent1 return is:  -76.30116769032199
# agent2 return is:  -10.563111816197253
# Batch 200 finished:
# agent1 return is:  -80.55672123783629
# agent2 return is:  -9.450585640596575
# Batch 200 finished:
# agent1 return is:  -80.55672123783629
# agent2 return is:  -9.450585640596575
# Batch 201 finished:
# agent1 return is:  -75.67656592665146
# agent2 return is:  -10.58759532736017
# Batch 201 finished:
# agent1 return is:  -75.67656592665146
# agent2 return is:  -10.58759532736017
# Batch 202 finished:
# agent1 return is:  -77.17673396189926
# agent2 return is:  -8.136513645719546
# Batch 202 finished:
# agent1 return is:  -77.17673396189926
# agent2 return is:  -8.136513645719546
# Batch 203 finished:
# agent1 return is:  -78.30201813784906
# agent2 return is:  -10.170691300787848
# Batch 203 finished:
# agent1 return is:  -78.30201813784906
# agent2 return is:  -10.170691300787848
# Batch 204 finished:
# agent1 return is:  -76.55404342969348
# agent2 return is:  -9.918297210419194
# Batch 204 finished:
# agent1 return is:  -76.55404342969348
# agent2 return is:  -9.918297210419194
# Batch 205 finished:
# agent1 return is:  -80.05377799555689
# agent2 return is:  -8.650069640130395
# Batch 205 finished:
# agent1 return is:  -80.05377799555689
# agent2 return is:  -8.650069640130395
# Batch 206 finished:
# agent1 return is:  -79.17966359389136
# agent2 return is:  -6.890724716470357
# Batch 206 finished:
# agent1 return is:  -79.17966359389136
# agent2 return is:  -6.890724716470357
# Batch 207 finished:
# agent1 return is:  -77.92914574707561
# agent2 return is:  -7.287302880785068
# Batch 207 finished:
# agent1 return is:  -77.92914574707561
# agent2 return is:  -7.287302880785068
# Batch 208 finished:
# agent1 return is:  -78.55451818023633
# agent2 return is:  -9.240609319050582
# Batch 208 finished:
# agent1 return is:  -78.55451818023633
# agent2 return is:  -9.240609319050582
# Batch 209 finished:
# agent1 return is:  -74.67340973169573
# agent2 return is:  -8.463081755849608
# Batch 209 finished:
# agent1 return is:  -74.67340973169573
# agent2 return is:  -8.463081755849608
# Batch 210 finished:
# agent1 return is:  -76.92817059107273
# agent2 return is:  -9.519386093405279
# Batch 210 finished:
# agent1 return is:  -76.92817059107273
# agent2 return is:  -9.519386093405279
# Batch 211 finished:
# agent1 return is:  -77.3019325902229
# agent2 return is:  -9.408246120949759
# Batch 211 finished:
# agent1 return is:  -77.3019325902229
# agent2 return is:  -9.408246120949759
# Batch 212 finished:
# agent1 return is:  -79.92817959274103
# agent2 return is:  -7.4266189040213355
# Batch 212 finished:
# agent1 return is:  -79.92817959274103
# agent2 return is:  -7.4266189040213355
# Batch 213 finished:
# agent1 return is:  -80.1805467035606
# agent2 return is:  -7.143459857201876
# Batch 213 finished:
# agent1 return is:  -80.1805467035606
# agent2 return is:  -7.143459857201876
# Batch 214 finished:
# agent1 return is:  -74.0495938164656
# agent2 return is:  -7.476792852282477
# Batch 214 finished:
# agent1 return is:  -74.0495938164656
# agent2 return is:  -7.476792852282477
# Batch 215 finished:
# agent1 return is:  -77.80235104401638
# agent2 return is:  -6.26176035350773
# Batch 215 finished:
# agent1 return is:  -77.80235104401638
# agent2 return is:  -6.26176035350773
# Batch 216 finished:
# agent1 return is:  -77.67818276003982
# agent2 return is:  -6.101170514737144
# Batch 216 finished:
# agent1 return is:  -77.67818276003982
# agent2 return is:  -6.101170514737144
# Batch 217 finished:
# agent1 return is:  -72.5493781149162
# agent2 return is:  -7.178615967185537
# Batch 217 finished:
# agent1 return is:  -72.5493781149162
# agent2 return is:  -7.178615967185537
# Batch 218 finished:
# agent1 return is:  -76.05069444297058
# agent2 return is:  -6.191962164303362
# Batch 218 finished:
# agent1 return is:  -76.05069444297058
# agent2 return is:  -6.191962164303362
# Batch 219 finished:
# agent1 return is:  -73.7979731568383
# agent2 return is:  -7.361550313670149
# Batch 219 finished:
# agent1 return is:  -73.7979731568383
# agent2 return is:  -7.361550313670149
# Batch 220 finished:
# agent1 return is:  -77.0502404027572
# agent2 return is:  -5.143883204152234
# Batch 220 finished:
# agent1 return is:  -77.0502404027572
# agent2 return is:  -5.143883204152234
# Batch 221 finished:
# agent1 return is:  -76.92673141784667
# agent2 return is:  -4.198007667987451
# Batch 221 finished:
# agent1 return is:  -76.92673141784667
# agent2 return is:  -4.198007667987451
# Batch 222 finished:
# agent1 return is:  -72.79748806175431
# agent2 return is:  -5.16963373625922
# Batch 222 finished:
# agent1 return is:  -72.79748806175431
# agent2 return is:  -5.16963373625922
# Batch 223 finished:
# agent1 return is:  -78.55033892327629
# agent2 return is:  -5.122752381575824
# Batch 223 finished:
# agent1 return is:  -78.55033892327629
# agent2 return is:  -5.122752381575824
# Batch 224 finished:
# agent1 return is:  -78.3003897940174
# agent2 return is:  -4.0112337798112065
# Batch 224 finished:
# agent1 return is:  -78.3003897940174
# agent2 return is:  -4.0112337798112065
# Batch 225 finished:
# agent1 return is:  -76.67303108225762
# agent2 return is:  -3.6894383327244586
# Batch 225 finished:
# agent1 return is:  -76.67303108225762
# agent2 return is:  -3.6894383327244586
# Batch 226 finished:
# agent1 return is:  -75.67633677361114
# agent2 return is:  -2.7790473900471695
# Batch 226 finished:
# agent1 return is:  -75.67633677361114
# agent2 return is:  -2.7790473900471695
# Batch 227 finished:
# agent1 return is:  -77.6766313805108
# agent2 return is:  -2.4532182044906246
# Batch 227 finished:
# agent1 return is:  -77.6766313805108
# agent2 return is:  -2.4532182044906246
# Batch 228 finished:
# agent1 return is:  -80.67534489695484
# agent2 return is:  -3.937404763389031
# Batch 228 finished:
# agent1 return is:  -80.67534489695484
# agent2 return is:  -3.937404763389031
# Batch 229 finished:
# agent1 return is:  -77.42508126799862
# agent2 return is:  -5.049932257366251
# Batch 229 finished:
# agent1 return is:  -77.42508126799862
# agent2 return is:  -5.049932257366251
# Batch 230 finished:
# agent1 return is:  -76.80412693967051
# agent2 return is:  -3.919720309106593
# Batch 230 finished:
# agent1 return is:  -76.80412693967051
# agent2 return is:  -3.919720309106593
# Batch 231 finished:
# agent1 return is:  -74.798989604837
# agent2 return is:  -3.023001010275638
# Batch 231 finished:
# agent1 return is:  -74.798989604837
# agent2 return is:  -3.023001010275638
# Batch 232 finished:
# agent1 return is:  -73.54857461785923
# agent2 return is:  -2.1506934875803854
# Batch 232 finished:
# agent1 return is:  -73.54857461785923
# agent2 return is:  -2.1506934875803854
# Batch 233 finished:
# agent1 return is:  -79.67945919079511
# agent2 return is:  -0.5762544757837085
# Batch 233 finished:
# agent1 return is:  -79.67945919079511
# agent2 return is:  -0.5762544757837085
# Batch 234 finished:
# agent1 return is:  -77.05255980303508
# agent2 return is:  -1.6857876723119534
# Batch 234 finished:
# agent1 return is:  -77.05255980303508
# agent2 return is:  -1.6857876723119534
# Batch 235 finished:
# agent1 return is:  -76.80307791863758
# agent2 return is:  -1.4310639714981117
# Batch 235 finished:
# agent1 return is:  -76.80307791863758
# agent2 return is:  -1.4310639714981117
# Batch 236 finished:
# agent1 return is:  -71.54663897266335
# agent2 return is:  -1.9113274082847957
# Batch 236 finished:
# agent1 return is:  -71.54663897266335
# agent2 return is:  -1.9113274082847957
# Batch 237 finished:
# agent1 return is:  -74.67352183335858
# agent2 return is:  -1.5664556490723502
# Batch 237 finished:
# agent1 return is:  -74.67352183335858
# agent2 return is:  -1.5664556490723502
# Batch 238 finished:
# agent1 return is:  -70.92253841070624
# agent2 return is:  0.45330907311720353
# Batch 238 finished:
# agent1 return is:  -70.92253841070624
# agent2 return is:  0.45330907311720353
# Batch 239 finished:
# agent1 return is:  -77.30176259644374
# agent2 return is:  -0.03751558090655749
# Batch 239 finished:
# agent1 return is:  -77.30176259644374
# agent2 return is:  -0.03751558090655749
# Batch 240 finished:
# agent1 return is:  -76.2990414852803
# agent2 return is:  -0.8686818170711577
# Batch 240 finished:
# agent1 return is:  -76.2990414852803
# agent2 return is:  -0.8686818170711577
# Batch 241 finished:
# agent1 return is:  -77.05213065095931
# agent2 return is:  -0.6655002925380684
# Batch 241 finished:
# agent1 return is:  -77.05213065095931
# agent2 return is:  -0.6655002925380684
# Batch 242 finished:
# agent1 return is:  -71.54143098940389
# agent2 return is:  -1.0276679108227504
# Batch 242 finished:
# agent1 return is:  -71.54143098940389
# agent2 return is:  -1.0276679108227504
# Batch 243 finished:
# agent1 return is:  -71.41855572693773
# agent2 return is:  0.18618348270668855
# Batch 243 finished:
# agent1 return is:  -71.41855572693773
# agent2 return is:  0.18618348270668855
# Batch 244 finished:
# agent1 return is:  -71.04574305436621
# agent2 return is:  -0.30462340784163805
# Batch 244 finished:
# agent1 return is:  -71.04574305436621
# agent2 return is:  -0.30462340784163805
# Batch 245 finished:
# agent1 return is:  -74.92247428242726
# agent2 return is:  1.356514412423249
# Batch 245 finished:
# agent1 return is:  -74.92247428242726
# agent2 return is:  1.356514412423249
# Batch 246 finished:
# agent1 return is:  -74.42584281691558
# agent2 return is:  0.6877417437572843
# Batch 246 finished:
# agent1 return is:  -74.42584281691558
# agent2 return is:  0.6877417437572843
# Batch 247 finished:
# agent1 return is:  -71.67145767701163
# agent2 return is:  1.6054682763214223
# Batch 247 finished:
# agent1 return is:  -71.67145767701163
# agent2 return is:  1.6054682763214223
# Batch 248 finished:
# agent1 return is:  -70.92112166543492
# agent2 return is:  0.003258858821946986
# Batch 248 finished:
# ...
# agent2 return is:  13.439490650718763
# Batch 4917 finished:
# agent1 return is:  1.1450610172405995
# agent2 return is:  13.439490650718763
# Batch 4918 finished:
# agent1 return is:  1.1456772895247762
# agent2 return is:  13.441422932895536
# Batch 4918 finished:
# agent1 return is:  1.1456772895247762
# agent2 return is:  13.441422932895536
# Batch 4919 finished:
# agent1 return is:  1.1432583924684583
# agent2 return is:  13.439797848751853
# Batch 4919 finished:
# agent1 return is:  1.1432583924684583
# agent2 return is:  13.439797848751853
# Batch 4920 finished:
# agent1 return is:  1.1448346550959199
# agent2 return is:  13.438899246116197
# Batch 4920 finished:
# agent1 return is:  1.1448346550959199
# agent2 return is:  13.438899246116197
# Batch 4921 finished:
# agent1 return is:  1.1428958314444677
# agent2 return is:  13.439978580988576
# Batch 4921 finished:
# agent1 return is:  1.1428958314444677
# agent2 return is:  13.439978580988576
# Batch 4922 finished:
# agent1 return is:  1.1424447856124984
# agent2 return is:  13.440139282846225
# Batch 4922 finished:
# agent1 return is:  1.1424447856124984
# agent2 return is:  13.440139282846225
# Batch 4923 finished:
# agent1 return is:  1.1431301045164721
# agent2 return is:  13.44011173456621
# Batch 4923 finished:
# agent1 return is:  1.1431301045164721
# agent2 return is:  13.44011173456621
# Batch 4924 finished:
# agent1 return is:  1.144310308806729
# agent2 return is:  13.439021526227304
# Batch 4924 finished:
# agent1 return is:  1.144310308806729
# agent2 return is:  13.439021526227304
# Batch 4925 finished:
# agent1 return is:  1.1438421192302268
# agent2 return is:  13.439325430982823
# Batch 4925 finished:
# agent1 return is:  1.1438421192302268
# agent2 return is:  13.439325430982823
# Batch 4926 finished:
# agent1 return is:  1.1413573861660737
# agent2 return is:  13.440273528369584
# Batch 4926 finished:
# agent1 return is:  1.1413573861660737
# agent2 return is:  13.440273528369584
# Batch 4927 finished:
# agent1 return is:  1.1421462428378149
# agent2 return is:  13.436872344413965
# Batch 4927 finished:
# agent1 return is:  1.1421462428378149
# agent2 return is:  13.436872344413965
# Batch 4928 finished:
# agent1 return is:  1.1446760651072265
# agent2 return is:  13.441433354374098
# Batch 4928 finished:
# agent1 return is:  1.1446760651072265
# agent2 return is:  13.441433354374098
# Batch 4929 finished:
# agent1 return is:  1.1437909111786586
# agent2 return is:  13.44056023406108
# Batch 4929 finished:
# agent1 return is:  1.1437909111786586
# agent2 return is:  13.44056023406108
# Batch 4930 finished:
# agent1 return is:  1.1426240861696404
# agent2 return is:  13.441009230620388
# Batch 4930 finished:
# agent1 return is:  1.1426240861696404
# agent2 return is:  13.441009230620388
# Batch 4931 finished:
# agent1 return is:  1.140983983380428
# agent2 return is:  13.436919463116439
# Batch 4931 finished:
# agent1 return is:  1.140983983380428
# agent2 return is:  13.436919463116439
# Batch 4932 finished:
# agent1 return is:  1.1413692908832442
# agent2 return is:  13.437609547766902
# Batch 4932 finished:
# agent1 return is:  1.1413692908832442
# agent2 return is:  13.437609547766902
# Batch 4933 finished:
# agent1 return is:  1.1393087504788784
# agent2 return is:  13.436236893616382
# Batch 4933 finished:
# agent1 return is:  1.1393087504788784
# agent2 return is:  13.436236893616382
# Batch 4934 finished:
# agent1 return is:  1.140759915084631
# agent2 return is:  13.439424187365564
# Batch 4934 finished:
# agent1 return is:  1.140759915084631
# agent2 return is:  13.439424187365564
# Batch 4935 finished:
# agent1 return is:  1.1406088997825623
# agent2 return is:  13.437281574356241
# Batch 4935 finished:
# agent1 return is:  1.1406088997825623
# agent2 return is:  13.437281574356241
# Batch 4936 finished:
# agent1 return is:  1.1422703582822196
# agent2 return is:  13.437424825104978
# Batch 4936 finished:
# agent1 return is:  1.1422703582822196
# agent2 return is:  13.437424825104978
# Batch 4937 finished:
# agent1 return is:  1.1411386224294788
# agent2 return is:  13.437291532210535
# Batch 4937 finished:
# agent1 return is:  1.1411386224294788
# agent2 return is:  13.437291532210535
# Batch 4938 finished:
# agent1 return is:  1.1395416235496747
# agent2 return is:  13.43565760903892
# Batch 4938 finished:
# agent1 return is:  1.1395416235496747
# agent2 return is:  13.43565760903892
# Batch 4939 finished:
# agent1 return is:  1.138670227331379
# agent2 return is:  13.435018924861698
# Batch 4939 finished:
# agent1 return is:  1.138670227331379
# agent2 return is:  13.435018924861698
# Batch 4940 finished:
# agent1 return is:  1.1392505114294615
# agent2 return is:  13.43480014434749
# Batch 4940 finished:
# agent1 return is:  1.1392505114294615
# agent2 return is:  13.43480014434749
# Batch 4941 finished:
# agent1 return is:  1.1385053048709088
# agent2 return is:  13.43508441094941
# Batch 4941 finished:
# agent1 return is:  1.1385053048709088
# agent2 return is:  13.43508441094941
# Batch 4942 finished:
# agent1 return is:  1.137351684501501
# agent2 return is:  13.43578108801479
# Batch 4942 finished:
# agent1 return is:  1.137351684501501
# agent2 return is:  13.43578108801479
# Batch 4943 finished:
# agent1 return is:  1.137937651626209
# agent2 return is:  13.435427904158761
# Batch 4943 finished:
# agent1 return is:  1.137937651626209
# agent2 return is:  13.435427904158761
# Batch 4944 finished:
# agent1 return is:  1.138467657474072
# agent2 return is:  13.437244983468947
# Batch 4944 finished:
# agent1 return is:  1.138467657474072
# agent2 return is:  13.437244983468947
# Batch 4945 finished:
# agent1 return is:  1.1377584817773196
# agent2 return is:  13.437646721300416
# Batch 4945 finished:
# agent1 return is:  1.1377584817773196
# agent2 return is:  13.437646721300416
# Batch 4946 finished:
# agent1 return is:  1.1360628833434694
# agent2 return is:  13.435028410109215
# Batch 4946 finished:
# agent1 return is:  1.1360628833434694
# agent2 return is:  13.435028410109215
# Batch 4947 finished:
# agent1 return is:  1.1375837530516086
# agent2 return is:  13.434180883881465
# Batch 4947 finished:
# agent1 return is:  1.1375837530516086
# agent2 return is:  13.434180883881465
# Batch 4948 finished:
# agent1 return is:  1.1371752338243752
# agent2 return is:  13.435037508997272
# Batch 4948 finished:
# agent1 return is:  1.1371752338243752
# agent2 return is:  13.435037508997272
# Batch 4949 finished:
# agent1 return is:  1.135739654556903
# agent2 return is:  13.433898251176343
# Batch 4949 finished:
# agent1 return is:  1.135739654556903
# agent2 return is:  13.433898251176343
# Batch 4950 finished:
# agent1 return is:  1.139162762103802
# agent2 return is:  13.437468805043554
# Batch 4950 finished:
# agent1 return is:  1.139162762103802
# agent2 return is:  13.437468805043554
# Batch 4951 finished:
# agent1 return is:  1.1384861405664506
# agent2 return is:  13.435817346154765
# Batch 4951 finished:
# agent1 return is:  1.1384861405664506
# agent2 return is:  13.435817346154765
# Batch 4952 finished:
# agent1 return is:  1.1378814078635546
# agent2 return is:  13.437691270670083
# Batch 4952 finished:
# agent1 return is:  1.1378814078635546
# agent2 return is:  13.437691270670083
# Batch 4953 finished:
# agent1 return is:  1.1361933107442155
# agent2 return is:  13.433567742565408
# Batch 4953 finished:
# agent1 return is:  1.1361933107442155
# agent2 return is:  13.433567742565408
# Batch 4954 finished:
# agent1 return is:  1.1382262576565956
# agent2 return is:  13.435533467931386
# Batch 4954 finished:
# agent1 return is:  1.1382262576565956
# agent2 return is:  13.435533467931386
# Batch 4955 finished:
# agent1 return is:  1.1390120110363369
# agent2 return is:  13.437112954452502
# Batch 4955 finished:
# agent1 return is:  1.1390120110363369
# agent2 return is:  13.437112954452502
# Batch 4956 finished:
# agent1 return is:  1.139020694030968
# agent2 return is:  13.43657549286241
# Batch 4956 finished:
# agent1 return is:  1.139020694030968
# agent2 return is:  13.43657549286241
# Batch 4957 finished:
# agent1 return is:  1.1395191662953192
# agent2 return is:  13.436141206560702
# Batch 4957 finished:
# agent1 return is:  1.1395191662953192
# agent2 return is:  13.436141206560702
# Batch 4958 finished:
# agent1 return is:  1.1389281235140534
# agent2 return is:  13.436311117876361
# Batch 4958 finished:
# agent1 return is:  1.1389281235140534
# agent2 return is:  13.436311117876361
# Batch 4959 finished:
# agent1 return is:  1.1372818895119625
# agent2 return is:  13.434797725758232
# Batch 4959 finished:
# agent1 return is:  1.1372818895119625
# agent2 return is:  13.434797725758232
# Batch 4960 finished:
# agent1 return is:  1.1370997028860281
# agent2 return is:  13.435497219802416
# Batch 4960 finished:
# agent1 return is:  1.1370997028860281
# agent2 return is:  13.435497219802416
# Batch 4961 finished:
# agent1 return is:  1.138123142443619
# agent2 return is:  13.435348258841747
# Batch 4961 finished:
# agent1 return is:  1.138123142443619
# agent2 return is:  13.435348258841747
# Batch 4962 finished:
# agent1 return is:  1.1377702571654655
# agent2 return is:  13.436529031614556
# Batch 4962 finished:
# agent1 return is:  1.1377702571654655
# agent2 return is:  13.436529031614556
# Batch 4963 finished:
# agent1 return is:  1.1374020427012588
# agent2 return is:  13.435521458908855
# Batch 4963 finished:
# agent1 return is:  1.1374020427012588
# agent2 return is:  13.435521458908855
# Batch 4964 finished:
# agent1 return is:  1.1387921404313524
# agent2 return is:  13.437213810303932
# Batch 4964 finished:
# agent1 return is:  1.1387921404313524
# agent2 return is:  13.437213810303932
# Batch 4965 finished:
# agent1 return is:  1.1387718885666431
# agent2 return is:  13.436304379285886
# Batch 4965 finished:
# agent1 return is:  1.1387718885666431
# agent2 return is:  13.436304379285886
# Batch 4966 finished:
# agent1 return is:  1.1374154359824284
# agent2 return is:  13.43724903244248
# Batch 4966 finished:
# agent1 return is:  1.1374154359824284
# agent2 return is:  13.43724903244248
# Batch 4967 finished:
# agent1 return is:  1.14011543230018
# agent2 return is:  13.437758073281
# Batch 4967 finished:
# agent1 return is:  1.14011543230018
# agent2 return is:  13.437758073281
# Batch 4968 finished:
# agent1 return is:  1.1397551877159346
# agent2 return is:  13.439830611895406
# Batch 4968 finished:
# agent1 return is:  1.1397551877159346
# agent2 return is:  13.439830611895406
# Batch 4969 finished:
# agent1 return is:  1.1402343468276772
# agent2 return is:  13.438329535918657
# Batch 4969 finished:
# agent1 return is:  1.1402343468276772
# agent2 return is:  13.438329535918657
# Batch 4970 finished:
# agent1 return is:  1.139408332358717
# agent2 return is:  13.435881808808363
# Batch 4970 finished:
# agent1 return is:  1.139408332358717
# agent2 return is:  13.435881808808363
# Batch 4971 finished:
# agent1 return is:  1.1389299248515208
# agent2 return is:  13.434813878940421
# Batch 4971 finished:
# agent1 return is:  1.1389299248515208
# agent2 return is:  13.434813878940421
# Batch 4972 finished:
# agent1 return is:  1.1402272782311529
# agent2 return is:  13.435418574392479
# Batch 4972 finished:
# agent1 return is:  1.1402272782311529
# agent2 return is:  13.435418574392479
# Batch 4973 finished:
# agent1 return is:  1.1406302231115433
# agent2 return is:  13.436400411874668
# Batch 4973 finished:
# agent1 return is:  1.1406302231115433
# agent2 return is:  13.436400411874668
# Batch 4974 finished:
# agent1 return is:  1.1410470834668696
# agent2 return is:  13.438513160530176
# Batch 4974 finished:
# agent1 return is:  1.1410470834668696
# agent2 return is:  13.438513160530176
# Batch 4975 finished:
# agent1 return is:  1.1402108656748395
# agent2 return is:  13.435884610651271
# Batch 4975 finished:
# agent1 return is:  1.1402108656748395
# agent2 return is:  13.435884610651271
# Batch 4976 finished:
# agent1 return is:  1.138862426194497
# agent2 return is:  13.436659024862323
# Batch 4976 finished:
# agent1 return is:  1.138862426194497
# agent2 return is:  13.436659024862323
# Batch 4977 finished:
# agent1 return is:  1.1399510487459248
# agent2 return is:  13.437862984730959
# Batch 4977 finished:
# agent1 return is:  1.1399510487459248
# agent2 return is:  13.437862984730959
# Batch 4978 finished:
# agent1 return is:  1.141482747402939
# agent2 return is:  13.437156981931881
# Batch 4978 finished:
# agent1 return is:  1.141482747402939
# agent2 return is:  13.437156981931881
# Batch 4979 finished:
# agent1 return is:  1.1402838278542324
# agent2 return is:  13.435723064755791
# Batch 4979 finished:
# agent1 return is:  1.1402838278542324
# agent2 return is:  13.435723064755791
# Batch 4980 finished:
# agent1 return is:  1.1395314033594435
# agent2 return is:  13.436316025918876
# Batch 4980 finished:
# agent1 return is:  1.1395314033594435
# agent2 return is:  13.436316025918876
# Batch 4981 finished:
# agent1 return is:  1.1383061235716885
# agent2 return is:  13.435911870833262
# Batch 4981 finished:
# agent1 return is:  1.1383061235716885
# agent2 return is:  13.435911870833262
# Batch 4982 finished:
# agent1 return is:  1.1392202374122924
# agent2 return is:  13.435631316302267
# Batch 4982 finished:
# agent1 return is:  1.1392202374122924
# agent2 return is:  13.435631316302267
# Batch 4983 finished:
# agent1 return is:  1.1389121349664546
# agent2 return is:  13.437463171368154
# Batch 4983 finished:
# agent1 return is:  1.1389121349664546
# agent2 return is:  13.437463171368154
# Batch 4984 finished:
# agent1 return is:  1.1398769597225948
# agent2 return is:  13.437346215331853
# Batch 4984 finished:
# agent1 return is:  1.1398769597225948
# agent2 return is:  13.437346215331853
# Batch 4985 finished:
# agent1 return is:  1.1397245014735233
# agent2 return is:  13.438375713645348
# Batch 4985 finished:
# agent1 return is:  1.1397245014735233
# agent2 return is:  13.438375713645348
# Batch 4986 finished:
# agent1 return is:  1.141546514238487
# agent2 return is:  13.436419739089594
# Batch 4986 finished:
# agent1 return is:  1.141546514238487
# agent2 return is:  13.436419739089594
# Batch 4987 finished:
# agent1 return is:  1.1402645815637933
# agent2 return is:  13.436693176548347
# Batch 4987 finished:
# agent1 return is:  1.1402645815637933
# agent2 return is:  13.436693176548347
# Batch 4988 finished:
# agent1 return is:  1.1399106164052908
# agent2 return is:  13.440691996252312
# Batch 4988 finished:
# agent1 return is:  1.1399106164052908
# agent2 return is:  13.440691996252312
# Batch 4989 finished:
# agent1 return is:  1.1405084494496407
# agent2 return is:  13.43943195279883
# Batch 4989 finished:
# agent1 return is:  1.1405084494496407
# agent2 return is:  13.43943195279883
# Batch 4990 finished:
# agent1 return is:  1.1409535271870883
# agent2 return is:  13.439885576334607
# Batch 4990 finished:
# agent1 return is:  1.1409535271870883
# agent2 return is:  13.439885576334607
# Batch 4991 finished:
# agent1 return is:  1.1407049292837197
# agent2 return is:  13.43708005769193
# Batch 4991 finished:
# agent1 return is:  1.1407049292837197
# agent2 return is:  13.43708005769193
# Batch 4992 finished:
# agent1 return is:  1.1406490353752878
# agent2 return is:  13.438589813951022
# Batch 4992 finished:
# agent1 return is:  1.1406490353752878
# agent2 return is:  13.438589813951022
# Batch 4993 finished:
# agent1 return is:  1.1413027156749214
# agent2 return is:  13.439153190777805
# Batch 4993 finished:
# agent1 return is:  1.1413027156749214
# agent2 return is:  13.439153190777805
# Batch 4994 finished:
# agent1 return is:  1.144303229631042
# agent2 return is:  13.440633875367872
# Batch 4994 finished:
# agent1 return is:  1.144303229631042
# agent2 return is:  13.440633875367872
# Batch 4995 finished:
# agent1 return is:  1.1456291235081362
# agent2 return is:  13.438515189923153
# Batch 4995 finished:
# agent1 return is:  1.1456291235081362
# agent2 return is:  13.438515189923153
# Batch 4996 finished:
# agent1 return is:  1.1437779356518165
# agent2 return is:  13.439115614918244
# Batch 4996 finished:
# agent1 return is:  1.1437779356518165
# agent2 return is:  13.439115614918244
# Batch 4997 finished:
# agent1 return is:  1.1447301485307537
# agent2 return is:  13.439752947279407
# Batch 4997 finished:
# agent1 return is:  1.1447301485307537
# agent2 return is:  13.439752947279407
# Batch 4998 finished:
# agent1 return is:  1.1448515851218453
# agent2 return is:  13.437354766734833
# Batch 4998 finished:
# agent1 return is:  1.1448515851218453
# agent2 return is:  13.437354766734833
# Batch 4999 finished:
# agent1 return is:  1.142795091809535
# agent2 return is:  13.441226326760315
# Batch 4999 finished:
# agent1 return is:  1.142795091809535
# agent2 return is:  13.441226326760315

# %%
agent1=tk.Agent("agent1",
				model=tm.Toy_Model_NE_Mut_1,
				actor_network=tk.NN,
				critic_network=tk.NN,
				clip=0.1,
				lr_actor=0.0001,
				lr_critic=0.001,
				grad_updates=1,
				optimizer_actor=torch.optim.Adam,
				optimizer_critic=torch.optim.Adam,       
				observables=['agent1','agent2','S',"A","B"],
				actions=['A_e','B_e'],
				gamma=1,
				)
agent2=tk.Agent("agent2",
				model=tm.Toy_Model_NE_Mut_2,
				actor_network=tk.NN,
				critic_network=tk.NN,
				clip=0.1,
				lr_actor=0.0001,
				lr_critic=0.001,
				grad_updates=1,
				optimizer_actor=torch.optim.Adam,
				optimizer_critic=torch.optim.Adam,       
				observables=['agent1','agent2','S',"A","B"],
				actions=['A_e','B_e'],
				gamma=1)
agents=[agent1,agent2]

env=tk.Environment(name="Toy-NECOM-Facultative",
 					agents=agents,
 					dilution_rate=0.0001,
 					extracellular_reactions=[],
 					initial_condition={"S":100,"agent1":0.1,"agent2":0.1,"A":10,"B":10},
 					inlet_conditions={"S":100},
 					max_c={'S':100,
 						   'agent1':10,  
 						   'agent2':10,
 						   'A':10,
 						   'B':10,},
 							dt=0.1,
 							episode_time=20,
 							number_of_batches=5000,
 							episodes_per_batch=int(NUM_CORES/2),)

env.rewards={agent.name:[] for agent in env.agents}
if not os.path.exists(f"Results/{env.name}"):
	os.makedirs(f"Results/{env.name}")
for agent in env.agents:
	agent.model.solver="glpk"
for batch in range(env.number_of_batches):
	batch_obs,batch_acts, batch_log_probs, batch_rtgs=tk.rollout(env)
	for agent in env.agents:
		V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
		A_k = batch_rtgs[agent.name] - V.detach()   
		A_k = (A_k - A_k.mean()) / (A_k.std() + 1e-5) 
		if batch==0:
			rich.print("[bold yellow] Hold on, bringing the creitc network to range...[/bold yellow]")
			err=21
			while err>20:
				V, _= agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
				critic_loss = nn.MSELoss()(V, batch_rtgs[agent.name])
				agent.optimizer_value_.zero_grad()
				critic_loss.backward()
				agent.optimizer_value_.step() 
				err=critic_loss.item()
			rich.print("[bold green] Done![/bold green]")
		else: 			
			for _ in range(agent.grad_updates):                                                      
				V, curr_log_probs = agent.evaluate(batch_obs[agent.name],batch_acts[agent.name])
				ratios = torch.exp(curr_log_probs - batch_log_probs[agent.name])
				surr1 = ratios * A_k.detach()
				surr2 = torch.clamp(ratios, 1 - agent.clip, 1 + agent.clip) * A_k
				actor_loss = (-torch.min(surr1, surr2)).mean()
				critic_loss = nn.MSELoss()(V, batch_rtgs[agent.name])
				agent.optimizer_policy_.zero_grad()
				actor_loss.backward(retain_graph=False)
				agent.optimizer_policy_.step()
				agent.optimizer_value_.zero_grad()
				critic_loss.backward()
				agent.optimizer_value_.step()                                                            	
		if batch%500==0:		
			with open(f"Results/{env.name}/{env.name}_{batch}.pkl", 'wb') as f:
				pickle.dump(env, f)
			with open(f"Results/{env.name}/observations_{batch}.pkl", 'wb') as f:
				pickle.dump(batch_obs,f)		
			with open(f"Results/{env.name}/actions_{batch}.pkl", 'wb') as f:
				pickle.dump(batch_acts,f)		
        		
		print(f"Batch {batch} finished:")
		for agent in env.agents:
			print(f"{agent.name} return is:  {np.mean(env.rewards[agent.name][-env.episodes_per_batch:])}")
# Out:
# Environment Toy-NECOM-Facultative created successfully!.
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
#  Hold on, bringing the creitc network to range...
#  Done!
# Batch 0 finished:
# agent1 return is:  -28.114913270986314
# agent2 return is:  -8.442885776386422
#  Hold on, bringing the creitc network to range...
#  Done!
# Batch 0 finished:
# agent1 return is:  -28.114913270986314
# agent2 return is:  -8.442885776386422
# Batch 1 finished:
# agent1 return is:  -27.88420291667081
# agent2 return is:  -8.946670081882866
# Batch 1 finished:
# agent1 return is:  -27.88420291667081
# agent2 return is:  -8.946670081882866
# Batch 2 finished:
# agent1 return is:  -26.36136426922207
# agent2 return is:  -8.704309789626535
# Batch 2 finished:
# agent1 return is:  -26.36136426922207
# agent2 return is:  -8.704309789626535
# Batch 3 finished:
# agent1 return is:  -26.124413740007213
# agent2 return is:  -7.210674053515518
# Batch 3 finished:
# agent1 return is:  -26.124413740007213
# agent2 return is:  -7.210674053515518
# Batch 4 finished:
# agent1 return is:  -25.098032069142185
# agent2 return is:  -8.960677758995805
# Batch 4 finished:
# agent1 return is:  -25.098032069142185
# agent2 return is:  -8.960677758995805
# Batch 5 finished:
# agent1 return is:  -25.859658208988343
# agent2 return is:  -10.208980300111897
# Batch 5 finished:
# agent1 return is:  -25.859658208988343
# agent2 return is:  -10.208980300111897
# Batch 6 finished:
# agent1 return is:  -24.85446625907288
# agent2 return is:  -12.954470403968266
# Batch 6 finished:
# agent1 return is:  -24.85446625907288
# agent2 return is:  -12.954470403968266
# Batch 7 finished:
# agent1 return is:  -25.5901778602362
# agent2 return is:  -9.697754635132025
# Batch 7 finished:
# agent1 return is:  -25.5901778602362
# agent2 return is:  -9.697754635132025
# Batch 8 finished:
# agent1 return is:  -27.1160097350978
# agent2 return is:  -10.21106271532629
# Batch 8 finished:
# agent1 return is:  -27.1160097350978
# agent2 return is:  -10.21106271532629
# Batch 9 finished:
# agent1 return is:  -26.086113435661986
# agent2 return is:  -9.97133432718186
# Batch 9 finished:
# agent1 return is:  -26.086113435661986
# agent2 return is:  -9.97133432718186
# Batch 10 finished:
# agent1 return is:  -24.34717332890063
# agent2 return is:  -10.70681430520618
# Batch 10 finished:
# agent1 return is:  -24.34717332890063
# agent2 return is:  -10.70681430520618
# Batch 11 finished:
# agent1 return is:  -24.887737887642352
# agent2 return is:  -8.43279513151906
# Batch 11 finished:
# agent1 return is:  -24.887737887642352
# agent2 return is:  -8.43279513151906
# Batch 12 finished:
# agent1 return is:  -24.860124453510025
# agent2 return is:  -9.184944565992339
# Batch 12 finished:
# agent1 return is:  -24.860124453510025
# agent2 return is:  -9.184944565992339
# Batch 13 finished:
# agent1 return is:  -27.371667355867242
# agent2 return is:  -8.70327161399775
# Batch 13 finished:
# agent1 return is:  -27.371667355867242
# agent2 return is:  -8.70327161399775
# Batch 14 finished:
# agent1 return is:  -28.59323126478717
# agent2 return is:  -9.702009687145841
# Batch 14 finished:
# agent1 return is:  -28.59323126478717
# agent2 return is:  -9.702009687145841
# Batch 15 finished:
# agent1 return is:  -25.88157792587691
# agent2 return is:  -8.456954493858262
# Batch 15 finished:
# agent1 return is:  -25.88157792587691
# agent2 return is:  -8.456954493858262
# Batch 16 finished:
# agent1 return is:  -25.372152547444863
# agent2 return is:  -9.951921741761362
# Batch 16 finished:
# agent1 return is:  -25.372152547444863
# agent2 return is:  -9.951921741761362
# Batch 17 finished:
# agent1 return is:  -26.340171542797343
# agent2 return is:  -8.950181470052843
# Batch 17 finished:
# agent1 return is:  -26.340171542797343
# agent2 return is:  -8.950181470052843
# Batch 18 finished:
# agent1 return is:  -23.59670470707832
# agent2 return is:  -10.218527594148357
# Batch 18 finished:
# agent1 return is:  -23.59670470707832
# agent2 return is:  -10.218527594148357
# Batch 19 finished:
# agent1 return is:  -26.397715731512314
# agent2 return is:  -11.943806895262234
# Batch 19 finished:
# agent1 return is:  -26.397715731512314
# agent2 return is:  -11.943806895262234
# Batch 20 finished:
# agent1 return is:  -23.379466438691967
# agent2 return is:  -11.945929345505172
# Batch 20 finished:
# agent1 return is:  -23.379466438691967
# agent2 return is:  -11.945929345505172
# Batch 21 finished:
# agent1 return is:  -27.363802963655353
# agent2 return is:  -10.708898064348137
# Batch 21 finished:
# agent1 return is:  -27.363802963655353
# agent2 return is:  -10.708898064348137
# Batch 22 finished:
# agent1 return is:  -25.623946491306793
# agent2 return is:  -7.944171244009981
# Batch 22 finished:
# agent1 return is:  -25.623946491306793
# agent2 return is:  -7.944171244009981
# Batch 23 finished:
# agent1 return is:  -25.103796291803413
# agent2 return is:  -12.206547367051964
# Batch 23 finished:
# agent1 return is:  -25.103796291803413
# agent2 return is:  -12.206547367051964
# Batch 24 finished:
# agent1 return is:  -24.579996356905536
# agent2 return is:  -9.484658760199315
# Batch 24 finished:
# agent1 return is:  -24.579996356905536
# agent2 return is:  -9.484658760199315
# Batch 25 finished:
# agent1 return is:  -28.351562945807053
# agent2 return is:  -9.718986027669239
# Batch 25 finished:
# agent1 return is:  -28.351562945807053
# agent2 return is:  -9.718986027669239
# Batch 26 finished:
# agent1 return is:  -26.846286673129995
# agent2 return is:  -9.469383080507663
# Batch 26 finished:
# agent1 return is:  -26.846286673129995
# agent2 return is:  -9.469383080507663
# Batch 27 finished:
# agent1 return is:  -24.617411960282197
# agent2 return is:  -10.4590737887948
# Batch 27 finished:
# agent1 return is:  -24.617411960282197
# agent2 return is:  -10.4590737887948
# Batch 28 finished:
# agent1 return is:  -27.352017021528432
# agent2 return is:  -8.211643087058821
# Batch 28 finished:
# agent1 return is:  -27.352017021528432
# agent2 return is:  -8.211643087058821
# Batch 29 finished:
# agent1 return is:  -26.612704775189243
# agent2 return is:  -9.940054036151668
# Batch 29 finished:
# agent1 return is:  -26.612704775189243
# agent2 return is:  -9.940054036151668
# Batch 30 finished:
# agent1 return is:  -25.60707919819476
# agent2 return is:  -10.713335075472171
# Batch 30 finished:
# agent1 return is:  -25.60707919819476
# agent2 return is:  -10.713335075472171
# Batch 31 finished:
# agent1 return is:  -26.852714902721125
# agent2 return is:  -9.69897756614867
# Batch 31 finished:
# agent1 return is:  -26.852714902721125
# agent2 return is:  -9.69897756614867
# Batch 32 finished:
# agent1 return is:  -26.850356277125293
# agent2 return is:  -11.181953507498525
# Batch 32 finished:
# agent1 return is:  -26.850356277125293
# agent2 return is:  -11.181953507498525
# Batch 33 finished:
# agent1 return is:  -28.111463044925568
# agent2 return is:  -9.948684394128362
# Batch 33 finished:
# agent1 return is:  -28.111463044925568
# agent2 return is:  -9.948684394128362
# Batch 34 finished:
# agent1 return is:  -25.60384476987498
# agent2 return is:  -9.952694916004
# Batch 34 finished:
# agent1 return is:  -25.60384476987498
# agent2 return is:  -9.952694916004
# Batch 35 finished:
# agent1 return is:  -25.61940755021287
# agent2 return is:  -8.945829396395641
# Batch 35 finished:
# agent1 return is:  -25.61940755021287
# agent2 return is:  -8.945829396395641
# Batch 36 finished:
# agent1 return is:  -23.109763993681653
# agent2 return is:  -11.433759198900347
# Batch 36 finished:
# agent1 return is:  -23.109763993681653
# agent2 return is:  -11.433759198900347
# Batch 37 finished:
# agent1 return is:  -25.357148749949992
# agent2 return is:  -10.456138941621903
# Batch 37 finished:
# agent1 return is:  -25.357148749949992
# agent2 return is:  -10.456138941621903
# Batch 38 finished:
# agent1 return is:  -27.092816927938735
# agent2 return is:  -10.463800582422667
# Batch 38 finished:
# agent1 return is:  -27.092816927938735
# agent2 return is:  -10.463800582422667
# Batch 39 finished:
# agent1 return is:  -27.12954520724269
# agent2 return is:  -11.21031305106023
# Batch 39 finished:
# agent1 return is:  -27.12954520724269
# agent2 return is:  -11.21031305106023
# Batch 40 finished:
# agent1 return is:  -29.124750173582097
# agent2 return is:  -8.7017160627349
# Batch 40 finished:
# agent1 return is:  -29.124750173582097
# agent2 return is:  -8.7017160627349
# Batch 41 finished:
# agent1 return is:  -25.110394702489195
# agent2 return is:  -9.479659149618263
# Batch 41 finished:
# agent1 return is:  -25.110394702489195
# agent2 return is:  -9.479659149618263
# Batch 42 finished:
# agent1 return is:  -26.856425224252348
# agent2 return is:  -8.449998101195252
# Batch 42 finished:
# agent1 return is:  -26.856425224252348
# agent2 return is:  -8.449998101195252
# Batch 43 finished:
# agent1 return is:  -27.851851588288596
# agent2 return is:  -10.461307073268035
# Batch 43 finished:
# agent1 return is:  -27.851851588288596
# agent2 return is:  -10.461307073268035
# Batch 44 finished:
# agent1 return is:  -28.090502546103387
# agent2 return is:  -7.467335815930928
# Batch 44 finished:
# agent1 return is:  -28.090502546103387
# agent2 return is:  -7.467335815930928
# Batch 45 finished:
# agent1 return is:  -26.604917973378235
# agent2 return is:  -9.946476537998922
# Batch 45 finished:
# agent1 return is:  -26.604917973378235
# agent2 return is:  -9.946476537998922
# Batch 46 finished:
# agent1 return is:  -27.351581607784723
# agent2 return is:  -9.46957880712554
# Batch 46 finished:
# agent1 return is:  -27.351581607784723
# agent2 return is:  -9.46957880712554
# Batch 47 finished:
# agent1 return is:  -26.621228339268406
# agent2 return is:  -9.42616385433524
# Batch 47 finished:
# agent1 return is:  -26.621228339268406
# agent2 return is:  -9.42616385433524
# Batch 48 finished:
# agent1 return is:  -27.352513781983244
# agent2 return is:  -9.195469111164549
# Batch 48 finished:
# agent1 return is:  -27.352513781983244
# agent2 return is:  -9.195469111164549
# Batch 49 finished:
# agent1 return is:  -25.344108609140534
# agent2 return is:  -9.71386460816185
# Batch 49 finished:
# agent1 return is:  -25.344108609140534
# agent2 return is:  -9.71386460816185
# Batch 50 finished:
# agent1 return is:  -25.61066242074066
# agent2 return is:  -9.2342024508193
# Batch 50 finished:
# agent1 return is:  -25.61066242074066
# agent2 return is:  -9.2342024508193
# Batch 51 finished:
# agent1 return is:  -23.58390855243552
# agent2 return is:  -12.247655704826425
# Batch 51 finished:
# agent1 return is:  -23.58390855243552
# agent2 return is:  -12.247655704826425
# Batch 52 finished:
# agent1 return is:  -23.87588549323425
# agent2 return is:  -12.455066489983068
# Batch 52 finished:
# agent1 return is:  -23.87588549323425
# agent2 return is:  -12.455066489983068
# Batch 53 finished:
# agent1 return is:  -23.60720975078539
# agent2 return is:  -9.197236245529655
# Batch 53 finished:
# agent1 return is:  -23.60720975078539
# agent2 return is:  -9.197236245529655
# Batch 54 finished:
# agent1 return is:  -25.864158271508245
# agent2 return is:  -8.93906948147659
# Batch 54 finished:
# agent1 return is:  -25.864158271508245
# agent2 return is:  -8.93906948147659
# Batch 55 finished:
# agent1 return is:  -26.605283537264324
# agent2 return is:  -9.437134442690787
# Batch 55 finished:
# agent1 return is:  -26.605283537264324
# agent2 return is:  -9.437134442690787
# Batch 56 finished:
# agent1 return is:  -25.355207449142032
# agent2 return is:  -8.466607743168646
# Batch 56 finished:
# agent1 return is:  -25.355207449142032
# agent2 return is:  -8.466607743168646
# Batch 57 finished:
# agent1 return is:  -23.34612570045477
# agent2 return is:  -10.959055224463404
# Batch 57 finished:
# agent1 return is:  -23.34612570045477
# agent2 return is:  -10.959055224463404
# Batch 58 finished:
# agent1 return is:  -26.60317923599267
# agent2 return is:  -9.455452946820182
# Batch 58 finished:
# agent1 return is:  -26.60317923599267
# agent2 return is:  -9.455452946820182
# Batch 59 finished:
# agent1 return is:  -25.842425022876164
# agent2 return is:  -9.708414248636258
# Batch 59 finished:
# agent1 return is:  -25.842425022876164
# agent2 return is:  -9.708414248636258
# Batch 60 finished:
# agent1 return is:  -26.8553783264815
# agent2 return is:  -8.94023684878071
# Batch 60 finished:
# agent1 return is:  -26.8553783264815
# agent2 return is:  -8.94023684878071
# Batch 61 finished:
# agent1 return is:  -25.852581818337605
# agent2 return is:  -10.452376576825486
# Batch 61 finished:
# agent1 return is:  -25.852581818337605
# agent2 return is:  -10.452376576825486
# Batch 62 finished:
# agent1 return is:  -24.33994846551164
# agent2 return is:  -10.456793759123986
# Batch 62 finished:
# agent1 return is:  -24.33994846551164
# agent2 return is:  -10.456793759123986
# Batch 63 finished:
# agent1 return is:  -25.10877003189183
# agent2 return is:  -10.969789635633187
# Batch 63 finished:
# agent1 return is:  -25.10877003189183
# agent2 return is:  -10.969789635633187
# Batch 64 finished:
# agent1 return is:  -26.35533300017133
# agent2 return is:  -8.715162589388973
# Batch 64 finished:
# agent1 return is:  -26.35533300017133
# agent2 return is:  -8.715162589388973
# Batch 65 finished:
# agent1 return is:  -26.11445436805506
# agent2 return is:  -9.948100083176683
# Batch 65 finished:
# agent1 return is:  -26.11445436805506
# agent2 return is:  -9.948100083176683
# Batch 66 finished:
# agent1 return is:  -28.613617681945232
# agent2 return is:  -9.93945209745296
# Batch 66 finished:
# agent1 return is:  -28.613617681945232
# agent2 return is:  -9.93945209745296
# Batch 67 finished:
# agent1 return is:  -25.84782365046548
# agent2 return is:  -9.460752529734592
# Batch 67 finished:
# agent1 return is:  -25.84782365046548
# agent2 return is:  -9.460752529734592
# Batch 68 finished:
# agent1 return is:  -25.36208948618724
# agent2 return is:  -8.699444754191596
# Batch 68 finished:
# agent1 return is:  -25.36208948618724
# agent2 return is:  -8.699444754191596
# Batch 69 finished:
# agent1 return is:  -25.590365449457984
# agent2 return is:  -10.435747741896765
# Batch 69 finished:
# agent1 return is:  -25.590365449457984
# agent2 return is:  -10.435747741896765
# Batch 70 finished:
# agent1 return is:  -26.859001311433914
# agent2 return is:  -9.43700334130819
# Batch 70 finished:
# agent1 return is:  -26.859001311433914
# agent2 return is:  -9.43700334130819
# Batch 71 finished:
# agent1 return is:  -24.086024307273757
# agent2 return is:  -10.964725844136545
# Batch 71 finished:
# agent1 return is:  -24.086024307273757
# agent2 return is:  -10.964725844136545
# Batch 72 finished:
# agent1 return is:  -27.59072890070121
# agent2 return is:  -7.961358625715516
# Batch 72 finished:
# agent1 return is:  -27.59072890070121
# agent2 return is:  -7.961358625715516
# Batch 73 finished:
# agent1 return is:  -26.362869882175914
# agent2 return is:  -10.702910063718384
# Batch 73 finished:
# agent1 return is:  -26.362869882175914
# agent2 return is:  -10.702910063718384
# Batch 74 finished:
# agent1 return is:  -24.840718861983827
# agent2 return is:  -9.212215786949788
# Batch 74 finished:
# agent1 return is:  -24.840718861983827
# agent2 return is:  -9.212215786949788
# Batch 75 finished:
# agent1 return is:  -23.609598999688913
# agent2 return is:  -8.953605810453134
# Batch 75 finished:
# agent1 return is:  -23.609598999688913
# agent2 return is:  -8.953605810453134
# Batch 76 finished:
# agent1 return is:  -23.601145246296515
# agent2 return is:  -10.959315662609688
# Batch 76 finished:
# agent1 return is:  -23.601145246296515
# agent2 return is:  -10.959315662609688
# Batch 77 finished:
# agent1 return is:  -23.834602731648086
# agent2 return is:  -9.206859252652135
# Batch 77 finished:
# agent1 return is:  -23.834602731648086
# agent2 return is:  -9.206859252652135
# Batch 78 finished:
# agent1 return is:  -26.835863889760077
# agent2 return is:  -8.199306184912405
# Batch 78 finished:
# agent1 return is:  -26.835863889760077
# agent2 return is:  -8.199306184912405
# Batch 79 finished:
# agent1 return is:  -27.6104842796355
# agent2 return is:  -8.933734027789143
# Batch 79 finished:
# agent1 return is:  -27.6104842796355
# agent2 return is:  -8.933734027789143
# Batch 80 finished:
# agent1 return is:  -25.078878064812905
# agent2 return is:  -8.479096037558566
# Batch 80 finished:
# agent1 return is:  -25.078878064812905
# agent2 return is:  -8.479096037558566
# Batch 81 finished:
# agent1 return is:  -26.332329286512508
# agent2 return is:  -8.72091467400309
# Batch 81 finished:
# agent1 return is:  -26.332329286512508
# agent2 return is:  -8.72091467400309
# Batch 82 finished:
# agent1 return is:  -23.82612930397268
# agent2 return is:  -9.698068744452364
# Batch 82 finished:
# agent1 return is:  -23.82612930397268
# agent2 return is:  -9.698068744452364
# Batch 83 finished:
# agent1 return is:  -26.843528508902324
# agent2 return is:  -7.452862857879975
# Batch 83 finished:
# agent1 return is:  -26.843528508902324
# agent2 return is:  -7.452862857879975
# Batch 84 finished:
# agent1 return is:  -23.085437383288244
# agent2 return is:  -12.219684324694938
# Batch 84 finished:
# agent1 return is:  -23.085437383288244
# agent2 return is:  -12.219684324694938
# Batch 85 finished:
# agent1 return is:  -25.59817060265482
# agent2 return is:  -8.43225928138261
# Batch 85 finished:
# agent1 return is:  -25.59817060265482
# agent2 return is:  -8.43225928138261
# Batch 86 finished:
# agent1 return is:  -26.354825488500914
# agent2 return is:  -10.692792817986989
# Batch 86 finished:
# agent1 return is:  -26.354825488500914
# agent2 return is:  -10.692792817986989
# Batch 87 finished:
# agent1 return is:  -25.829080865613047
# agent2 return is:  -9.232178005605626
# Batch 87 finished:
# agent1 return is:  -25.829080865613047
# agent2 return is:  -9.232178005605626
# Batch 88 finished:
# agent1 return is:  -27.10892525627351
# agent2 return is:  -8.433848375608259
# Batch 88 finished:
# agent1 return is:  -27.10892525627351
# agent2 return is:  -8.433848375608259
# Batch 89 finished:
# agent1 return is:  -25.81995737892238
# agent2 return is:  -10.963337450909854
# Batch 89 finished:
# agent1 return is:  -25.81995737892238
# agent2 return is:  -10.963337450909854
# Batch 90 finished:
# agent1 return is:  -22.570409729835653
# agent2 return is:  -10.192769893506323
# Batch 90 finished:
# agent1 return is:  -22.570409729835653
# agent2 return is:  -10.192769893506323
# Batch 91 finished:
# agent1 return is:  -24.59926511258513
# agent2 return is:  -12.225424648673814
# Batch 91 finished:
# agent1 return is:  -24.59926511258513
# agent2 return is:  -12.225424648673814
# Batch 92 finished:
# agent1 return is:  -26.341873709547333
# agent2 return is:  -7.704525168087033
# Batch 92 finished:
# agent1 return is:  -26.341873709547333
# agent2 return is:  -7.704525168087033
# Batch 93 finished:
# agent1 return is:  -26.602538074177485
# agent2 return is:  -11.209192715752893
# Batch 93 finished:
# agent1 return is:  -26.602538074177485
# agent2 return is:  -11.209192715752893
# Batch 94 finished:
# agent1 return is:  -25.32363902736736
# agent2 return is:  -9.980425855534145
# Batch 94 finished:
# agent1 return is:  -25.32363902736736
# agent2 return is:  -9.980425855534145
# Batch 95 finished:
# agent1 return is:  -26.58372184315328
# agent2 return is:  -7.686444555083241
# Batch 95 finished:
# agent1 return is:  -26.58372184315328
# agent2 return is:  -7.686444555083241
# Batch 96 finished:
# agent1 return is:  -24.853945973903116
# agent2 return is:  -9.915610673593692
# Batch 96 finished:
# agent1 return is:  -24.853945973903116
# agent2 return is:  -9.915610673593692
# Batch 97 finished:
# agent1 return is:  -23.833918885380093
# agent2 return is:  -9.697297153367131
# Batch 97 finished:
# agent1 return is:  -23.833918885380093
# agent2 return is:  -9.697297153367131
# Batch 98 finished:
# agent1 return is:  -25.84498757799355
# agent2 return is:  -10.926096541551567
# Batch 98 finished:
# agent1 return is:  -25.84498757799355
# agent2 return is:  -10.926096541551567
# Batch 99 finished:
# agent1 return is:  -26.35420374184654
# agent2 return is:  -10.690859832372997
# Batch 99 finished:
# agent1 return is:  -26.35420374184654
# agent2 return is:  -10.690859832372997
# Batch 100 finished:
# agent1 return is:  -24.336301611589313
# agent2 return is:  -10.68664647361299
# Batch 100 finished:
# agent1 return is:  -24.336301611589313
# agent2 return is:  -10.68664647361299
# Batch 101 finished:
# agent1 return is:  -21.841096882779006
# agent2 return is:  -10.695528503452318
# Batch 101 finished:
# agent1 return is:  -21.841096882779006
# agent2 return is:  -10.695528503452318
# Batch 102 finished:
# agent1 return is:  -26.077259916149508
# agent2 return is:  -8.204769198343339
# Batch 102 finished:
# agent1 return is:  -26.077259916149508
# agent2 return is:  -8.204769198343339
# Batch 103 finished:
# agent1 return is:  -25.096331352425736
# agent2 return is:  -10.957460584559687
# Batch 103 finished:
# agent1 return is:  -25.096331352425736
# agent2 return is:  -10.957460584559687
# Batch 104 finished:
# agent1 return is:  -25.857082612754038
# agent2 return is:  -8.177092396187788
# Batch 104 finished:
# agent1 return is:  -25.857082612754038
# agent2 return is:  -8.177092396187788
# Batch 105 finished:
# agent1 return is:  -25.836164761417624
# agent2 return is:  -9.947652204128865
# Batch 105 finished:
# agent1 return is:  -25.836164761417624
# agent2 return is:  -9.947652204128865
# Batch 106 finished:
# agent1 return is:  -27.062248952771053
# agent2 return is:  -9.705424002072512
# Batch 106 finished:
# agent1 return is:  -27.062248952771053
# agent2 return is:  -9.705424002072512
# Batch 107 finished:
# agent1 return is:  -24.09378700549474
# agent2 return is:  -10.718118740210924
# Batch 107 finished:
# agent1 return is:  -24.09378700549474
# agent2 return is:  -10.718118740210924
# Batch 108 finished:
# agent1 return is:  -22.589429955828532
# agent2 return is:  -11.70102314017508
# Batch 108 finished:
# agent1 return is:  -22.589429955828532
# agent2 return is:  -11.70102314017508
# Batch 109 finished:
# agent1 return is:  -26.10139908438718
# agent2 return is:  -8.446135533788798
# Batch 109 finished:
# agent1 return is:  -26.10139908438718
# agent2 return is:  -8.446135533788798
# Batch 110 finished:
# agent1 return is:  -24.579061490436672
# agent2 return is:  -7.468082996924611
# Batch 110 finished:
# agent1 return is:  -24.579061490436672
# agent2 return is:  -7.468082996924611
# Batch 111 finished:
# agent1 return is:  -26.092481874727536
# agent2 return is:  -9.94777514328904
# Batch 111 finished:
# agent1 return is:  -26.092481874727536
# agent2 return is:  -9.94777514328904
# Batch 112 finished:
# agent1 return is:  -26.589227579772228
# agent2 return is:  -8.446788905006873
# Batch 112 finished:
# agent1 return is:  -26.589227579772228
# agent2 return is:  -8.446788905006873
# Batch 113 finished:
# agent1 return is:  -23.344781574431096
# agent2 return is:  -8.44536501798476
# Batch 113 finished:
# agent1 return is:  -23.344781574431096
# agent2 return is:  -8.44536501798476
# Batch 114 finished:
# agent1 return is:  -24.338233427660427
# agent2 return is:  -10.206546176403682
# Batch 114 finished:
# agent1 return is:  -24.338233427660427
# agent2 return is:  -10.206546176403682
# Batch 115 finished:
# agent1 return is:  -25.095241014938278
# agent2 return is:  -9.433126364266078
# Batch 115 finished:
# agent1 return is:  -25.095241014938278
# agent2 return is:  -9.433126364266078
# Batch 116 finished:
# agent1 return is:  -24.848245248083252
# agent2 return is:  -7.44705170090605
# Batch 116 finished:
# agent1 return is:  -24.848245248083252
# agent2 return is:  -7.44705170090605
# Batch 117 finished:
# agent1 return is:  -26.342441022977898
# agent2 return is:  -10.200411533161121
# Batch 117 finished:
# agent1 return is:  -26.342441022977898
# agent2 return is:  -10.200411533161121
# Batch 118 finished:
# agent1 return is:  -24.084372920180126
# agent2 return is:  -11.700511561405701
# Batch 118 finished:
# agent1 return is:  -24.084372920180126
# agent2 return is:  -11.700511561405701
# Batch 119 finished:
# agent1 return is:  -25.821704431571014
# agent2 return is:  -7.948248097421161
# Batch 119 finished:
# agent1 return is:  -25.821704431571014
# agent2 return is:  -7.948248097421161
# Batch 120 finished:
# agent1 return is:  -25.564671007785158
# agent2 return is:  -9.4655149030185
# Batch 120 finished:
# agent1 return is:  -25.564671007785158
# agent2 return is:  -9.4655149030185
# Batch 121 finished:
# agent1 return is:  -23.07970233029021
# agent2 return is:  -8.714272172623943
# Batch 121 finished:
# agent1 return is:  -23.07970233029021
# agent2 return is:  -8.714272172623943
# Batch 122 finished:
# agent1 return is:  -23.597876914709772
# agent2 return is:  -12.699777543804213
# Batch 122 finished:
# agent1 return is:  -23.597876914709772
# agent2 return is:  -12.699777543804213
# Batch 123 finished:
# agent1 return is:  -25.840017500473138
# agent2 return is:  -11.948778106361912
# Batch 123 finished:
# agent1 return is:  -25.840017500473138
# agent2 return is:  -11.948778106361912
# Batch 124 finished:
# agent1 return is:  -25.33716948639173
# agent2 return is:  -8.696791706008689
# Batch 124 finished:
# agent1 return is:  -25.33716948639173
# agent2 return is:  -8.696791706008689
# Batch 125 finished:
# agent1 return is:  -23.086027926948244
# agent2 return is:  -8.697030516864068
# Batch 125 finished:
# agent1 return is:  -23.086027926948244
# agent2 return is:  -8.697030516864068
# Batch 126 finished:
# agent1 return is:  -26.5915431531597
# agent2 return is:  -8.934265038903646
# Batch 126 finished:
# agent1 return is:  -26.5915431531597
# agent2 return is:  -8.934265038903646
# Batch 127 finished:
# agent1 return is:  -23.556576804223255
# agent2 return is:  -10.220771011136334
# Batch 127 finished:
# agent1 return is:  -23.556576804223255
# agent2 return is:  -10.220771011136334
# Batch 128 finished:
# agent1 return is:  -25.3334342065435
# agent2 return is:  -10.950839493432436
# Batch 128 finished:
# agent1 return is:  -25.3334342065435
# agent2 return is:  -10.950839493432436
# Batch 129 finished:
# agent1 return is:  -26.3201696173447
# agent2 return is:  -9.209576646473357
# Batch 129 finished:
# agent1 return is:  -26.3201696173447
# agent2 return is:  -9.209576646473357
# Batch 130 finished:
# agent1 return is:  -22.552688186271425
# agent2 return is:  -10.98499655403674
# Batch 130 finished:
# agent1 return is:  -22.552688186271425
# agent2 return is:  -10.98499655403674
# Batch 131 finished:
# agent1 return is:  -24.082133648504183
# agent2 return is:  -8.719039022930318
# Batch 131 finished:
# agent1 return is:  -24.082133648504183
# agent2 return is:  -8.719039022930318
# Batch 132 finished:
# agent1 return is:  -24.577551312369224
# agent2 return is:  -7.694653371543822
# Batch 132 finished:
# agent1 return is:  -24.577551312369224
# agent2 return is:  -7.694653371543822
# Batch 133 finished:
# agent1 return is:  -25.07820147423893
# agent2 return is:  -8.949238220002158
# Batch 133 finished:
# agent1 return is:  -25.07820147423893
# agent2 return is:  -8.949238220002158
# Batch 134 finished:
# agent1 return is:  -23.570826063277554
# agent2 return is:  -8.720466438731492
# Batch 134 finished:
# agent1 return is:  -23.570826063277554
# agent2 return is:  -8.720466438731492
# Batch 135 finished:
# agent1 return is:  -23.328029752017855
# agent2 return is:  -9.93630292379331
# Batch 135 finished:
# agent1 return is:  -23.328029752017855
# agent2 return is:  -9.93630292379331
# Batch 136 finished:
# agent1 return is:  -24.073023590384086
# agent2 return is:  -11.456333590128736
# Batch 136 finished:
# agent1 return is:  -24.073023590384086
# agent2 return is:  -11.456333590128736
# Batch 137 finished:
# agent1 return is:  -24.07594286208684
# agent2 return is:  -10.716526290739242
# Batch 137 finished:
# agent1 return is:  -24.07594286208684
# agent2 return is:  -10.716526290739242
# Batch 138 finished:
# agent1 return is:  -25.068323961025456
# agent2 return is:  -8.72014554895468
# Batch 138 finished:
# agent1 return is:  -25.068323961025456
# agent2 return is:  -8.72014554895468
# Batch 139 finished:
# agent1 return is:  -24.57642923321511
# agent2 return is:  -10.952648196575582
# Batch 139 finished:
# agent1 return is:  -24.57642923321511
# agent2 return is:  -10.952648196575582
# Batch 140 finished:
# agent1 return is:  -23.818484032201898
# agent2 return is:  -8.958690758073011
# Batch 140 finished:
# agent1 return is:  -23.818484032201898
# agent2 return is:  -8.958690758073011
# Batch 141 finished:
# agent1 return is:  -23.843851267680563
# agent2 return is:  -8.442783992843802
# Batch 141 finished:
# agent1 return is:  -23.843851267680563
# agent2 return is:  -8.442783992843802
# Batch 142 finished:
# agent1 return is:  -24.825860125071568
# agent2 return is:  -9.196602173384939
# Batch 142 finished:
# agent1 return is:  -24.825860125071568
# agent2 return is:  -9.196602173384939
# Batch 143 finished:
# agent1 return is:  -22.809556934494886
# agent2 return is:  -9.210367997976856
# Batch 143 finished:
# agent1 return is:  -22.809556934494886
# agent2 return is:  -9.210367997976856
# Batch 144 finished:
# agent1 return is:  -24.821070695500303
# agent2 return is:  -7.93590113906205
# Batch 144 finished:
# agent1 return is:  -24.821070695500303
# agent2 return is:  -7.93590113906205
# Batch 145 finished:
# agent1 return is:  -25.807252624151914
# agent2 return is:  -10.20714871273795
# Batch 145 finished:
# agent1 return is:  -25.807252624151914
# agent2 return is:  -10.20714871273795
# Batch 146 finished:
# agent1 return is:  -24.336600913594154
# agent2 return is:  -10.691424432296174
# Batch 146 finished:
# agent1 return is:  -24.336600913594154
# agent2 return is:  -10.691424432296174
# Batch 147 finished:
# agent1 return is:  -24.080720302495425
# agent2 return is:  -10.474407823450653
# Batch 147 finished:
# agent1 return is:  -24.080720302495425
# agent2 return is:  -10.474407823450653
# Batch 148 finished:
# agent1 return is:  -27.076355296471146
# agent2 return is:  -8.439043458010856
# Batch 148 finished:
# agent1 return is:  -27.076355296471146
# agent2 return is:  -8.439043458010856
# Batch 149 finished:
# agent1 return is:  -25.81833958898693
# agent2 return is:  -10.439246873346182
# Batch 149 finished:
# agent1 return is:  -25.81833958898693
# agent2 return is:  -10.439246873346182
# Batch 150 finished:
# agent1 return is:  -25.301865839617776
# agent2 return is:  -9.44665749134871
# Batch 150 finished:
# agent1 return is:  -25.301865839617776
# agent2 return is:  -9.44665749134871
# Batch 151 finished:
# agent1 return is:  -22.82354194683971
# agent2 return is:  -10.710475341209168
# Batch 151 finished:
# agent1 return is:  -22.82354194683971
# agent2 return is:  -10.710475341209168
# Batch 152 finished:
# agent1 return is:  -25.084795278422263
# agent2 return is:  -8.69752924378253
# Batch 152 finished:
# agent1 return is:  -25.084795278422263
# agent2 return is:  -8.69752924378253
# Batch 153 finished:
# agent1 return is:  -25.300677872245398
# agent2 return is:  -9.188115533070413
# Batch 153 finished:
# agent1 return is:  -25.300677872245398
# agent2 return is:  -9.188115533070413
# Batch 154 finished:
# agent1 return is:  -24.820149313792854
# agent2 return is:  -9.688027960245158
# Batch 154 finished:
# agent1 return is:  -24.820149313792854
# agent2 return is:  -9.688027960245158
# Batch 155 finished:
# agent1 return is:  -23.5765848916821
# agent2 return is:  -10.20005820075018
# Batch 155 finished:
# agent1 return is:  -23.5765848916821
# agent2 return is:  -10.20005820075018
# Batch 156 finished:
# agent1 return is:  -23.81845106594933
# agent2 return is:  -11.706624635351673
# Batch 156 finished:
# agent1 return is:  -23.81845106594933
# agent2 return is:  -11.706624635351673
# Batch 157 finished:
# agent1 return is:  -26.812391496076078
# agent2 return is:  -10.459130697804213
# Batch 157 finished:
# agent1 return is:  -26.812391496076078
# agent2 return is:  -10.459130697804213
# Batch 158 finished:
# agent1 return is:  -25.31945678844915
# agent2 return is:  -10.459081289019455
# Batch 158 finished:
# agent1 return is:  -25.31945678844915
# agent2 return is:  -10.459081289019455
# Batch 159 finished:
# agent1 return is:  -23.072343923454245
# agent2 return is:  -8.703670660808934
# Batch 159 finished:
# agent1 return is:  -23.072343923454245
# agent2 return is:  -8.703670660808934
# Batch 160 finished:
# agent1 return is:  -21.82693994642017
# agent2 return is:  -10.69025083772043
# Batch 160 finished:
# agent1 return is:  -21.82693994642017
# agent2 return is:  -10.69025083772043
# Batch 161 finished:
# agent1 return is:  -24.316974635442936
# agent2 return is:  -9.949299312664898
# Batch 161 finished:
# agent1 return is:  -24.316974635442936
# agent2 return is:  -9.949299312664898
# Batch 162 finished:
# agent1 return is:  -25.55767434330319
# agent2 return is:  -11.198934803643633
# Batch 162 finished:
# agent1 return is:  -25.55767434330319
# agent2 return is:  -11.198934803643633
# Batch 163 finished:
# agent1 return is:  -26.312951775267717
# agent2 return is:  -9.467453015311293
# Batch 163 finished:
# agent1 return is:  -26.312951775267717
# agent2 return is:  -9.467453015311293
# Batch 164 finished:
# agent1 return is:  -24.315846334838575
# agent2 return is:  -10.959995971627436
# Batch 164 finished:
# agent1 return is:  -24.315846334838575
# agent2 return is:  -10.959995971627436
# Batch 165 finished:
# agent1 return is:  -26.068297082412812
# agent2 return is:  -10.690157846066107
# Batch 165 finished:
# agent1 return is:  -26.068297082412812
# agent2 return is:  -10.690157846066107
# Batch 166 finished:
# agent1 return is:  -23.314299432394666
# agent2 return is:  -8.698374581778106
# Batch 166 finished:
# agent1 return is:  -23.314299432394666
# agent2 return is:  -8.698374581778106
# Batch 167 finished:
# agent1 return is:  -25.543770644383546
# agent2 return is:  -8.208755360393923
# Batch 167 finished:
# agent1 return is:  -25.543770644383546
# agent2 return is:  -8.208755360393923
# Batch 168 finished:
# agent1 return is:  -26.045956021537645
# agent2 return is:  -9.43750247256749
# Batch 168 finished:
# agent1 return is:  -26.045956021537645
# agent2 return is:  -9.43750247256749
# Batch 169 finished:
# agent1 return is:  -24.569153165563606
# agent2 return is:  -10.952120980065951
# Batch 169 finished:
# agent1 return is:  -24.569153165563606
# agent2 return is:  -10.952120980065951
# Batch 170 finished:
# agent1 return is:  -22.565301788505398
# agent2 return is:  -8.958978475834268
# Batch 170 finished:
# agent1 return is:  -22.565301788505398
# agent2 return is:  -8.958978475834268
# Batch 171 finished:
# agent1 return is:  -25.06876990706348
# agent2 return is:  -8.913914034824852
# Batch 171 finished:
# agent1 return is:  -25.06876990706348
# agent2 return is:  -8.913914034824852
# Batch 172 finished:
# agent1 return is:  -22.566394232714437
# agent2 return is:  -10.95113220026425
# Batch 172 finished:
# agent1 return is:  -22.566394232714437
# agent2 return is:  -10.95113220026425
# Batch 173 finished:
# agent1 return is:  -21.305764815805688
# agent2 return is:  -10.715326155681666
# Batch 173 finished:
# agent1 return is:  -21.305764815805688
# agent2 return is:  -10.715326155681666
# Batch 174 finished:
# agent1 return is:  -27.573195361263178
# agent2 return is:  -7.954120592969512
# Batch 174 finished:
# agent1 return is:  -27.573195361263178
# agent2 return is:  -7.954120592969512
# Batch 175 finished:
# agent1 return is:  -24.298422312903792
# agent2 return is:  -9.70422274661222
# Batch 175 finished:
# agent1 return is:  -24.298422312903792
# agent2 return is:  -9.70422274661222
# Batch 176 finished:
# agent1 return is:  -25.07799037732652
# agent2 return is:  -9.198231035716958
# Batch 176 finished:
# agent1 return is:  -25.07799037732652
# agent2 return is:  -9.198231035716958
# Batch 177 finished:
# agent1 return is:  -25.070143679882943
# agent2 return is:  -7.189331780330188
# Batch 177 finished:
# agent1 return is:  -25.070143679882943
# agent2 return is:  -7.189331780330188
# Batch 178 finished:
# agent1 return is:  -23.791670524476338
# agent2 return is:  -8.439914033666195
# Batch 178 finished:
# agent1 return is:  -23.791670524476338
# agent2 return is:  -8.439914033666195
# Batch 179 finished:
# agent1 return is:  -24.557134345110097
# agent2 return is:  -10.183209860132497
# Batch 179 finished:
# agent1 return is:  -24.557134345110097
# agent2 return is:  -10.183209860132497
# Batch 180 finished:
# agent1 return is:  -24.821261088593307
# agent2 return is:  -8.930228851162555
# Batch 180 finished:
# agent1 return is:  -24.821261088593307
# agent2 return is:  -8.930228851162555
# Batch 181 finished:
# agent1 return is:  -23.555248880257487
# agent2 return is:  -11.196118861986024
# Batch 181 finished:
# agent1 return is:  -23.555248880257487
# agent2 return is:  -11.196118861986024
# Batch 182 finished:
# agent1 return is:  -23.060285837531218
# agent2 return is:  -9.189160917453307
# Batch 182 finished:
# agent1 return is:  -23.060285837531218
# agent2 return is:  -9.189160917453307
# Batch 183 finished:
# agent1 return is:  -23.567393812112932
# agent2 return is:  -9.188113381731126
# Batch 183 finished:
# agent1 return is:  -23.567393812112932
# agent2 return is:  -9.188113381731126
# Batch 184 finished:
# agent1 return is:  -21.047779090909795
# agent2 return is:  -11.691021739227464
# Batch 184 finished:
# agent1 return is:  -21.047779090909795
# agent2 return is:  -11.691021739227464
# Batch 185 finished:
# agent1 return is:  -25.05455360990176
# agent2 return is:  -9.452759707767397
# Batch 185 finished:
# agent1 return is:  -25.05455360990176
# agent2 return is:  -9.452759707767397
# Batch 186 finished:
# agent1 return is:  -22.78488146203032
# agent2 return is:  -10.472206226344891
# Batch 186 finished:
# agent1 return is:  -22.78488146203032
# agent2 return is:  -10.472206226344891
# Batch 187 finished:
# agent1 return is:  -21.292627813196503
# agent2 return is:  -13.205709675015497
# Batch 187 finished:
# agent1 return is:  -21.292627813196503
# agent2 return is:  -13.205709675015497
# Batch 188 finished:
# agent1 return is:  -21.544523353640926
# agent2 return is:  -11.198552227326264
# Batch 188 finished:
# agent1 return is:  -21.544523353640926
# agent2 return is:  -11.198552227326264
# Batch 189 finished:
# agent1 return is:  -23.56779099348077
# agent2 return is:  -10.952378601378376
# Batch 189 finished:
# agent1 return is:  -23.56779099348077
# agent2 return is:  -10.952378601378376
# Batch 190 finished:
# agent1 return is:  -23.060463595498618
# agent2 return is:  -7.94787010977253
# Batch 190 finished:
# agent1 return is:  -23.060463595498618
# agent2 return is:  -7.94787010977253
# Batch 191 finished:
# agent1 return is:  -23.307550574987584
# agent2 return is:  -11.941216879267856
# Batch 191 finished:
# agent1 return is:  -23.307550574987584
# agent2 return is:  -11.941216879267856
# Batch 192 finished:
# agent1 return is:  -24.586250215970026
# agent2 return is:  -9.192555334876026
# Batch 192 finished:
# agent1 return is:  -24.586250215970026
# agent2 return is:  -9.192555334876026
# Batch 193 finished:
# agent1 return is:  -26.309700242969605
# agent2 return is:  -9.44343970221745
# Batch 193 finished:
# agent1 return is:  -26.309700242969605
# agent2 return is:  -9.44343970221745
# Batch 194 finished:
# agent1 return is:  -23.787300742619674
# agent2 return is:  -10.214572722976776
# Batch 194 finished:
# agent1 return is:  -23.787300742619674
# agent2 return is:  -10.214572722976776
# Batch 195 finished:
# agent1 return is:  -19.5733310899776
# agent2 return is:  -10.693067813316638
# Batch 195 finished:
# agent1 return is:  -19.5733310899776
# agent2 return is:  -10.693067813316638
# Batch 196 finished:
# agent1 return is:  -22.797728045923314
# agent2 return is:  -10.941490714066932
# Batch 196 finished:
# agent1 return is:  -22.797728045923314
# agent2 return is:  -10.941490714066932
# Batch 197 finished:
# agent1 return is:  -24.553180264411186
# agent2 return is:  -8.686518487976002
# Batch 197 finished:
# agent1 return is:  -24.553180264411186
# agent2 return is:  -8.686518487976002
# Batch 198 finished:
# agent1 return is:  -21.80739997280327
# agent2 return is:  -8.467552610054202
# Batch 198 finished:
# agent1 return is:  -21.80739997280327
# agent2 return is:  -8.467552610054202
# Batch 199 finished:
# agent1 return is:  -23.299135759765136
# agent2 return is:  -10.206603444732723
# Batch 199 finished:
# agent1 return is:  -23.299135759765136
# agent2 return is:  -10.206603444732723
# Batch 200 finished:
# agent1 return is:  -23.06068855618159
# agent2 return is:  -11.186994421507118
# Batch 200 finished:
# agent1 return is:  -23.06068855618159
# agent2 return is:  -11.186994421507118
# Batch 201 finished:
# agent1 return is:  -24.317708165602188
# agent2 return is:  -12.675847830164692
# Batch 201 finished:
# agent1 return is:  -24.317708165602188
# agent2 return is:  -12.675847830164692
# Batch 202 finished:
# agent1 return is:  -24.796843040181617
# agent2 return is:  -8.435984975359846
# Batch 202 finished:
# agent1 return is:  -24.796843040181617
# agent2 return is:  -8.435984975359846
# Batch 203 finished:
# agent1 return is:  -21.040529370511937
# agent2 return is:  -10.212341720738912
# Batch 203 finished:
# agent1 return is:  -21.040529370511937
# agent2 return is:  -10.212341720738912
# Batch 204 finished:
# agent1 return is:  -22.547409772662842
# agent2 return is:  -10.687941238480096
# Batch 204 finished:
# agent1 return is:  -22.547409772662842
# agent2 return is:  -10.687941238480096
# Batch 205 finished:
# agent1 return is:  -24.29259291812629
# agent2 return is:  -9.71667078763086
# Batch 205 finished:
# agent1 return is:  -24.29259291812629
# agent2 return is:  -9.71667078763086
# Batch 206 finished:
# agent1 return is:  -25.305872892345057
# agent2 return is:  -9.690319496951261
# Batch 206 finished:
# agent1 return is:  -25.305872892345057
# agent2 return is:  -9.690319496951261
# Batch 207 finished:
# agent1 return is:  -21.778440062380014
# agent2 return is:  -8.471496238029642
# Batch 207 finished:
# agent1 return is:  -21.778440062380014
# agent2 return is:  -8.471496238029642
# Batch 208 finished:
# agent1 return is:  -22.30361493105166
# agent2 return is:  -10.960826738832012
# Batch 208 finished:
# agent1 return is:  -22.30361493105166
# agent2 return is:  -10.960826738832012
# Batch 209 finished:
# agent1 return is:  -25.04983542658986
# agent2 return is:  -7.942199657850058
# Batch 209 finished:
# agent1 return is:  -25.04983542658986
# agent2 return is:  -7.942199657850058
# Batch 210 finished:
# agent1 return is:  -23.79838312556507
# agent2 return is:  -9.19333597133845
# Batch 210 finished:
# agent1 return is:  -23.79838312556507
# agent2 return is:  -9.19333597133845
# Batch 211 finished:
# agent1 return is:  -22.059627922905438
# agent2 return is:  -12.447001036891407
# Batch 211 finished:
# agent1 return is:  -22.059627922905438
# agent2 return is:  -12.447001036891407
# Batch 212 finished:
# agent1 return is:  -26.79770207253609
# agent2 return is:  -8.436397613005862
# Batch 212 finished:
# agent1 return is:  -26.79770207253609
# agent2 return is:  -8.436397613005862
# Batch 213 finished:
# agent1 return is:  -25.539642110047108
# agent2 return is:  -9.180236814211542
# Batch 213 finished:
# agent1 return is:  -25.539642110047108
# agent2 return is:  -9.180236814211542
# Batch 214 finished:
# agent1 return is:  -25.303617218089453
# agent2 return is:  -8.198270216464167
# Batch 214 finished:
# agent1 return is:  -25.303617218089453
# agent2 return is:  -8.198270216464167
# Batch 215 finished:
# agent1 return is:  -19.29981593445428
# agent2 return is:  -10.188252926321859
# Batch 215 finished:
# agent1 return is:  -19.29981593445428
# agent2 return is:  -10.188252926321859
# Batch 216 finished:
# agent1 return is:  -26.040475928563254
# agent2 return is:  -7.705584060348601
# Batch 216 finished:
# agent1 return is:  -26.040475928563254
# agent2 return is:  -7.705584060348601
# Batch 217 finished:
# agent1 return is:  -25.053661044139613
# agent2 return is:  -7.95201416425049
# Batch 217 finished:
# agent1 return is:  -25.053661044139613
# agent2 return is:  -7.95201416425049
# Batch 218 finished:
# agent1 return is:  -22.30277793618668
# agent2 return is:  -8.694622938009537
# Batch 218 finished:
# agent1 return is:  -22.30277793618668
# agent2 return is:  -8.694622938009537
# Batch 219 finished:
# agent1 return is:  -23.78444482807931
# agent2 return is:  -10.21337780686201
# Batch 219 finished:
# agent1 return is:  -23.78444482807931
# agent2 return is:  -10.21337780686201
# Batch 220 finished:
# agent1 return is:  -21.77477773001651
# agent2 return is:  -8.449045090699304
# Batch 220 finished:
# agent1 return is:  -21.77477773001651
# agent2 return is:  -8.449045090699304
# Batch 221 finished:
# agent1 return is:  -23.049166090913406
# agent2 return is:  -10.687030102493011
# Batch 221 finished:
# agent1 return is:  -23.049166090913406
# agent2 return is:  -10.687030102493011
# Batch 222 finished:
# agent1 return is:  -22.52708295688867
# agent2 return is:  -11.712596539087787
# Batch 222 finished:
# agent1 return is:  -22.52708295688867
# agent2 return is:  -11.712596539087787
# Batch 223 finished:
# agent1 return is:  -23.797594415069202
# agent2 return is:  -10.205172341169156
# Batch 223 finished:
# agent1 return is:  -23.797594415069202
# agent2 return is:  -10.205172341169156
# Batch 224 finished:
# agent1 return is:  -20.533836396083586
# agent2 return is:  -10.207519156740553
# Batch 224 finished:
# agent1 return is:  -20.533836396083586
# agent2 return is:  -10.207519156740553
# Batch 225 finished:
# agent1 return is:  -21.797429580089613
# agent2 return is:  -12.704457591576121
# Batch 225 finished:
# agent1 return is:  -21.797429580089613
# agent2 return is:  -12.704457591576121
# Batch 226 finished:
# agent1 return is:  -21.543545119830092
# agent2 return is:  -10.686144154955423
# Batch 226 finished:
# agent1 return is:  -21.543545119830092
# agent2 return is:  -10.686144154955423
# Batch 227 finished:
# agent1 return is:  -22.041028684968914
# agent2 return is:  -10.700152730295976
# Batch 227 finished:
# agent1 return is:  -22.041028684968914
# agent2 return is:  -10.700152730295976
# Batch 228 finished:
# agent1 return is:  -21.276335237011814
# agent2 return is:  -9.685613413330989
# Batch 228 finished:
# agent1 return is:  -21.276335237011814
# agent2 return is:  -9.685613413330989
# Batch 229 finished:
# agent1 return is:  -23.297876460536923
# agent2 return is:  -10.445781746178863
# Batch 229 finished:
# agent1 return is:  -23.297876460536923
# agent2 return is:  -10.445781746178863
# Batch 230 finished:
# agent1 return is:  -19.558614688287488
# agent2 return is:  -10.6850053842272
# Batch 230 finished:
# agent1 return is:  -19.558614688287488
# agent2 return is:  -10.6850053842272
# Batch 231 finished:
# agent1 return is:  -21.037476378482275
# agent2 return is:  -9.949112564344787
# Batch 231 finished:
# agent1 return is:  -21.037476378482275
# agent2 return is:  -9.949112564344787
# Batch 232 finished:
# agent1 return is:  -23.797631360193623
# agent2 return is:  -11.20178489346228
# Batch 232 finished:
# agent1 return is:  -23.797631360193623
# agent2 return is:  -11.20178489346228
# Batch 233 finished:
# agent1 return is:  -23.04317610000579
# agent2 return is:  -9.690533176861177
# Batch 233 finished:
# agent1 return is:  -23.04317610000579
# agent2 return is:  -9.690533176861177
# Batch 234 finished:
# agent1 return is:  -25.289625985394405
# agent2 return is:  -10.708150339422948
# Batch 234 finished:
# agent1 return is:  -25.289625985394405
# agent2 return is:  -10.708150339422948
# Batch 235 finished:
# agent1 return is:  -25.077024702934686
# agent2 return is:  -8.42508784722084
# Batch 235 finished:
# agent1 return is:  -25.077024702934686
# agent2 return is:  -8.42508784722084
# Batch 236 finished:
# agent1 return is:  -22.788467534723793
# agent2 return is:  -9.722117503632063
# Batch 236 finished:
# agent1 return is:  -22.788467534723793
# agent2 return is:  -9.722117503632063
# Batch 237 finished:
# agent1 return is:  -23.53748537131323
# agent2 return is:  -8.963025614229887
# Batch 237 finished:
# agent1 return is:  -23.53748537131323
# agent2 return is:  -8.963025614229887
# Batch 238 finished:
# agent1 return is:  -20.782044404153222
# agent2 return is:  -10.225591357093874
# Batch 238 finished:
# agent1 return is:  -20.782044404153222
# agent2 return is:  -10.225591357093874
# Batch 239 finished:
# agent1 return is:  -22.059909504804605
# agent2 return is:  -9.673968087481585
# Batch 239 finished:
# agent1 return is:  -22.059909504804605
# agent2 return is:  -9.673968087481585
# Batch 240 finished:
# agent1 return is:  -26.041125225435074
# agent2 return is:  -7.68314428703874
# Batch 240 finished:
# agent1 return is:  -26.041125225435074
# agent2 return is:  -7.68314428703874
# Batch 241 finished:
# agent1 return is:  -21.285748369947335
# agent2 return is:  -8.452293639697022
# Batch 241 finished:
# agent1 return is:  -21.285748369947335
# agent2 return is:  -8.452293639697022
# Batch 242 finished:
# agent1 return is:  -22.527748863031157
# agent2 return is:  -10.450537395939325
# Batch 242 finished:
# agent1 return is:  -22.527748863031157
# agent2 return is:  -10.450537395939325
# Batch 243 finished:
# agent1 return is:  -25.29348279816292
# agent2 return is:  -9.932163135030049
# Batch 243 finished:
# agent1 return is:  -25.29348279816292
# agent2 return is:  -9.932163135030049
# Batch 244 finished:
# agent1 return is:  -22.54117677608628
# agent2 return is:  -8.684419334292585
# Batch 244 finished:
# agent1 return is:  -22.54117677608628
# agent2 return is:  -8.684419334292585
# Batch 245 finished:
# agent1 return is:  -24.78811550197387
# agent2 return is:  -10.215043622907373
# Batch 245 finished:
# agent1 return is:  -24.78811550197387
# agent2 return is:  -10.215043622907373
# Batch 246 finished:
# agent1 return is:  -21.779889587600557
# agent2 return is:  -10.944455313475572
# Batch 246 finished:
# agent1 return is:  -21.779889587600557
# agent2 return is:  -10.944455313475572
# Batch 247 finished:
# agent1 return is:  -22.53542897290059
# ...
# Batch 4915 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4916 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4916 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4917 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4917 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4918 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4918 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4919 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4919 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4920 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4920 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4921 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4921 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4922 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4922 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4923 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4923 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4924 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4924 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4925 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4925 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4926 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4926 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4927 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4927 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4928 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4928 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4929 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4929 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4930 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4930 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4931 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4931 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4932 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4932 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4933 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4933 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4934 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4934 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4935 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4935 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4936 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4936 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4937 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4937 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4938 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4938 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4939 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4939 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4940 finished:
# agent1 return is:  5.3901603148571455
# agent2 return is:  5.390071283833416
# Batch 4940 finished:
# agent1 return is:  5.3901603148571455
# agent2 return is:  5.390071283833416
# Batch 4941 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4941 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4942 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4942 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4943 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4943 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4944 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4944 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4945 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4945 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4946 finished:
# agent1 return is:  5.390122428196628
# agent2 return is:  5.390109188188262
# Batch 4946 finished:
# agent1 return is:  5.390122428196628
# agent2 return is:  5.390109188188262
# Batch 4947 finished:
# agent1 return is:  5.140104195509442
# agent2 return is:  5.39011580970576
# Batch 4947 finished:
# agent1 return is:  5.140104195509442
# agent2 return is:  5.39011580970576
# Batch 4948 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4948 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4949 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4949 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4950 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4950 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4951 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4951 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4952 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4952 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4953 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4953 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4954 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4954 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4955 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4955 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4956 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4956 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4957 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4957 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4958 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4958 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4959 finished:
# agent1 return is:  5.390117469966437
# agent2 return is:  5.390114148714135
# Batch 4959 finished:
# agent1 return is:  5.390117469966437
# agent2 return is:  5.390114148714135
# Batch 4960 finished:
# agent1 return is:  5.390406876110429
# agent2 return is:  5.3898246126612275
# Batch 4960 finished:
# agent1 return is:  5.390406876110429
# agent2 return is:  5.3898246126612275
# Batch 4961 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4961 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4962 finished:
# agent1 return is:  5.390273462182984
# agent2 return is:  5.389958087141913
# Batch 4962 finished:
# agent1 return is:  5.390273462182984
# agent2 return is:  5.389958087141913
# Batch 4963 finished:
# agent1 return is:  5.3901355463157685
# agent2 return is:  5.390096064153208
# Batch 4963 finished:
# agent1 return is:  5.3901355463157685
# agent2 return is:  5.390096064153208
# Batch 4964 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4964 finished:
# agent1 return is:  5.390115809705761
# agent2 return is:  5.39011580970576
# Batch 4965 finished:
# agent1 return is:  5.390379917198981
# agent2 return is:  5.389851584644353
# Batch 4965 finished:
# agent1 return is:  5.390379917198981
# agent2 return is:  5.389851584644353
# Batch 4966 finished:
# agent1 return is:  5.3907930960591495
# agent2 return is:  5.389438211086796
# Batch 4966 finished:
# agent1 return is:  5.3907930960591495
# agent2 return is:  5.389438211086796
# Batch 4967 finished:
# agent1 return is:  5.390174179583598
# agent2 return is:  5.3900574126518155
# Batch 4967 finished:
# agent1 return is:  5.390174179583598
# agent2 return is:  5.3900574126518155
# Batch 4968 finished:
# agent1 return is:  5.390192909190402
# agent2 return is:  5.390038674642923
# Batch 4968 finished:
# agent1 return is:  5.390192909190402
# agent2 return is:  5.390038674642923
# Batch 4969 finished:
# agent1 return is:  5.391065243467494
# agent2 return is:  5.3891659479985154
# Batch 4969 finished:
# agent1 return is:  5.391065243467494
# agent2 return is:  5.3891659479985154
# Batch 4970 finished:
# agent1 return is:  5.390502165089179
# agent2 return is:  5.3897292788338005
# Batch 4970 finished:
# agent1 return is:  5.390502165089179
# agent2 return is:  5.3897292788338005
# Batch 4971 finished:
# agent1 return is:  5.3913733500199115
# agent2 return is:  5.3888576992041965
# Batch 4971 finished:
# agent1 return is:  5.3913733500199115
# agent2 return is:  5.3888576992041965
# Batch 4972 finished:
# agent1 return is:  5.392162344272572
# agent2 return is:  5.388068356088425
# Batch 4972 finished:
# agent1 return is:  5.392162344272572
# agent2 return is:  5.388068356088425
# Batch 4973 finished:
# agent1 return is:  5.391340337756659
# agent2 return is:  5.38889073732388
# Batch 4973 finished:
# agent1 return is:  5.391340337756659
# agent2 return is:  5.38889073732388
# Batch 4974 finished:
# agent1 return is:  5.390403740273381
# agent2 return is:  5.389827750665777
# Batch 4974 finished:
# agent1 return is:  5.390403740273381
# agent2 return is:  5.389827750665777
# Batch 4975 finished:
# agent1 return is:  5.390941886875326
# agent2 return is:  5.389289363261673
# Batch 4975 finished:
# agent1 return is:  5.390941886875326
# agent2 return is:  5.389289363261673
# Batch 4976 finished:
# agent1 return is:  5.391083497101264
# agent2 return is:  5.3891476920922265
# Batch 4976 finished:
# agent1 return is:  5.391083497101264
# agent2 return is:  5.3891476920922265
# Batch 4977 finished:
# agent1 return is:  5.391463714192888
# agent2 return is:  5.3887672892549
# Batch 4977 finished:
# agent1 return is:  5.391463714192888
# agent2 return is:  5.3887672892549
# Batch 4978 finished:
# agent1 return is:  5.393167292001492
# agent2 return is:  5.38706295228681
# Batch 4978 finished:
# agent1 return is:  5.393167292001492
# agent2 return is:  5.38706295228681
# Batch 4979 finished:
# agent1 return is:  5.393252265894663
# agent2 return is:  5.386977931036301
# Batch 4979 finished:
# agent1 return is:  5.393252265894663
# agent2 return is:  5.386977931036301
# Batch 4980 finished:
# agent1 return is:  5.393088911613719
# agent2 return is:  5.38714135396606
# Batch 4980 finished:
# agent1 return is:  5.393088911613719
# agent2 return is:  5.38714135396606
# Batch 4981 finished:
# agent1 return is:  5.394501846427981
# agent2 return is:  5.38572778501739
# Batch 4981 finished:
# agent1 return is:  5.394501846427981
# agent2 return is:  5.38572778501739
# Batch 4982 finished:
# agent1 return is:  5.392534469060939
# agent2 return is:  5.387696053811941
# Batch 4982 finished:
# agent1 return is:  5.392534469060939
# agent2 return is:  5.387696053811941
# Batch 4983 finished:
# agent1 return is:  5.391753343653472
# agent2 return is:  5.388477536904174
# Batch 4983 finished:
# agent1 return is:  5.391753343653472
# agent2 return is:  5.388477536904174
# Batch 4984 finished:
# agent1 return is:  5.3938646191573625
# agent2 return is:  5.386365296746367
# Batch 4984 finished:
# agent1 return is:  5.3938646191573625
# agent2 return is:  5.386365296746367
# Batch 4985 finished:
# agent1 return is:  5.391063937851189
# agent2 return is:  5.38916724772619
# Batch 4985 finished:
# agent1 return is:  5.391063937851189
# agent2 return is:  5.38916724772619
# Batch 4986 finished:
# agent1 return is:  5.391879320754036
# agent2 return is:  5.38835150048744
# Batch 4986 finished:
# agent1 return is:  5.391879320754036
# agent2 return is:  5.38835150048744
# Batch 4987 finished:
# agent1 return is:  5.391069691064467
# agent2 return is:  5.38916151192797
# Batch 4987 finished:
# agent1 return is:  5.391069691064467
# agent2 return is:  5.38916151192797
# Batch 4988 finished:
# agent1 return is:  5.392312315715038
# agent2 return is:  5.387918295695048
# Batch 4988 finished:
# agent1 return is:  5.392312315715038
# agent2 return is:  5.387918295695048
# Batch 4989 finished:
# agent1 return is:  5.391422452089931
# agent2 return is:  5.38880855947817
# Batch 4989 finished:
# agent1 return is:  5.391422452089931
# agent2 return is:  5.38880855947817
# Batch 4990 finished:
# agent1 return is:  5.391048195359292
# agent2 return is:  5.389183003644997
# Batch 4990 finished:
# agent1 return is:  5.391048195359292
# agent2 return is:  5.389183003644997
# Batch 4991 finished:
# agent1 return is:  5.391476892123703
# agent2 return is:  5.388754105473632
# Batch 4991 finished:
# agent1 return is:  5.391476892123703
# agent2 return is:  5.388754105473632
# Batch 4992 finished:
# agent1 return is:  5.391170907730526
# agent2 return is:  5.389060241140128
# Batch 4992 finished:
# agent1 return is:  5.391170907730526
# agent2 return is:  5.389060241140128
# Batch 4993 finished:
# agent1 return is:  5.390765713438173
# agent2 return is:  5.389465614394167
# Batch 4993 finished:
# agent1 return is:  5.390765713438173
# agent2 return is:  5.389465614394167
# Batch 4994 finished:
# agent1 return is:  5.391213902406634
# agent2 return is:  5.389017224726364
# Batch 4994 finished:
# agent1 return is:  5.391213902406634
# agent2 return is:  5.389017224726364
# Batch 4995 finished:
# agent1 return is:  5.39022871547875
# agent2 return is:  5.390002855058393
# Batch 4995 finished:
# agent1 return is:  5.39022871547875
# agent2 return is:  5.390002855058393
# Batch 4996 finished:
# agent1 return is:  5.390737548316608
# agent2 return is:  5.389493780735382
# Batch 4996 finished:
# agent1 return is:  5.390737548316608
# agent2 return is:  5.389493780735382
# Batch 4997 finished:
# agent1 return is:  5.391609166877079
# agent2 return is:  5.388621761161934
# Batch 4997 finished:
# agent1 return is:  5.391609166877079
# agent2 return is:  5.388621761161934
# Batch 4998 finished:
# agent1 return is:  5.390252928215027
# agent2 return is:  5.389978628489143
# Batch 4998 finished:
# agent1 return is:  5.390252928215027
# agent2 return is:  5.389978628489143
# Batch 4999 finished:
# agent1 return is:  5.390198086509733
# agent2 return is:  5.3900334956117755
# Batch 4999 finished:
# agent1 return is:  5.390198086509733
# agent2 return is:  5.3900334956117755
